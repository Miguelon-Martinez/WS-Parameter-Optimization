# %% [markdown]
# ## Cálculo de $V_0$ y $V_{LS}$ para la energía de los niveles inferior y superior de Fermi para distintos isótopos.

# %% [markdown]
# NOTA: Cambiar la variable camino / file_path / os.chdir según el fichero en el que estemos trabajando

# %% [markdown]
# Primero vamos a crear una pequeña base de datos con la energía de los distintos núcleos y sus paridades, a partir de la tabla que aparece en las prácticas

# %%
## Librerías que vamos a utilizar

import numpy as np
import pandas as pd

# %%
# Crear los datos
data = {
    'Núcleo': [
        '5Li', '5He', '3He', '3H', '4He',
        '13N', '13C', '11C', '11B', '12C',
        '17F', '17O', '15O', '15N', '16O',
        '41Sc', '41Ca', '39Ca', '39K', '40Ca',
        '49Sc', '49Ca', '47Ca', '47K', '48Ca',
        '91Nb', '91Zr', '89Zr', '89Y', '90Zr',
        '149Tb', '147Gd', '145Gd', '145Eu', '146Gd',
        '209Bi', '209Pb', '207Pb', '207Tl', '208Pb'
    ],
    'Δ (MeV)': [
        11.685, 11.390, 14.930, 14.950, 2.420,
        5.436, 3.125, 10.650, 8.668, 0.000,
        1.952, -0.810, 2.855, 0.102, -4.737,
        -28.644, -35.139, -27.282, -33.806, -34.847,
        -46.555, -41.286, -42.343, -35.698, -44.216,
        -86.637, -87.893, -84.860, -87.695, -89.765,
        -70.510, -75.207, -72.940, -77.936, -75.361,
        -18.268, -17.624, -22.463, -21.041, -21.759
    ],
    'Jπ': [
        '3/2−', '3/2−', '1/2+', '1/2+', '0+',
        '1/2−', '1/2−', '3/2−', '3/2−', '0+',
        '5/2+', '5/2+', '1/2−', '1/2−', '0+',
        '7/2−', '7/2−', '3/2+', '3/2+', '0+',
        '7/2−', '3/2−', '7/2−', '1/2+', '0+',
        '9/2+', '5/2+', '9/2+', '1/2−', '0+',
        '11/2−', '7/2−', '1/2+', '5/2+', '0+',
        '9/2−', '9/2+', '1/2−', '1/2+', '0+'
    ],

## Metemos Z y A pa poder mejorar el código -> A partir de El núcleo, se meten A y Z y se suman y restan para las energías.

    'Z': [
        3, 2, 2, 1, 2,
        7, 6, 6, 5, 6,
        9, 8, 8, 7, 8,
        21, 20, 20, 19, 20,
        21, 20, 20, 19, 20,
        41, 40, 40, 39, 40,
        65, 64, 64, 63, 64,
        83, 82, 82, 81, 82
    ],
    'A': [
        5, 5, 3, 3, 4,
        13, 13, 11, 11, 12,
        17, 17, 15, 15, 16,
        41, 41, 39, 39, 40,
        49, 49, 47, 47, 48,
        91, 91, 89, 89, 90,
        149, 147, 145, 145, 146,
        209, 209, 207, 207, 208
    ]
}

# Crear el DataFrame
df = pd.DataFrame(data)

df['N'] = df['A'] - df['Z']

df['R'] = round(1.2 * df['A']**(1/3),2)

# Mostrar el DataFrame
df
# Out:
#    Núcleo  Δ (MeV)     Jπ   Z    A    N     R
# 0     5Li   11.685   3/2−   3    5    2  2.05
# 1     5He   11.390   3/2−   2    5    3  2.05
# 2     3He   14.930   1/2+   2    3    1  1.73
# 3      3H   14.950   1/2+   1    3    2  1.73
# 4     4He    2.420     0+   2    4    2  1.90
# 5     13N    5.436   1/2−   7   13    6  2.82
# 6     13C    3.125   1/2−   6   13    7  2.82
# 7     11C   10.650   3/2−   6   11    5  2.67
# 8     11B    8.668   3/2−   5   11    6  2.67
# 9     12C    0.000     0+   6   12    6  2.75
# 10    17F    1.952   5/2+   9   17    8  3.09
# 11    17O   -0.810   5/2+   8   17    9  3.09
# 12    15O    2.855   1/2−   8   15    7  2.96
# 13    15N    0.102   1/2−   7   15    8  2.96
# 14    16O   -4.737     0+   8   16    8  3.02
# 15   41Sc  -28.644   7/2−  21   41   20  4.14
# 16   41Ca  -35.139   7/2−  20   41   21  4.14
# 17   39Ca  -27.282   3/2+  20   39   19  4.07
# 18    39K  -33.806   3/2+  19   39   20  4.07
# 19   40Ca  -34.847     0+  20   40   20  4.10
# 20   49Sc  -46.555   7/2−  21   49   28  4.39
# 21   49Ca  -41.286   3/2−  20   49   29  4.39
# 22   47Ca  -42.343   7/2−  20   47   27  4.33
# 23    47K  -35.698   1/2+  19   47   28  4.33
# 24   48Ca  -44.216     0+  20   48   28  4.36
# 25   91Nb  -86.637   9/2+  41   91   50  5.40
# 26   91Zr  -87.893   5/2+  40   91   51  5.40
# 27   89Zr  -84.860   9/2+  40   89   49  5.36
# 28    89Y  -87.695   1/2−  39   89   50  5.36
# 29   90Zr  -89.765     0+  40   90   50  5.38
# 30  149Tb  -70.510  11/2−  65  149   84  6.36
# 31  147Gd  -75.207   7/2−  64  147   83  6.33
# 32  145Gd  -72.940   1/2+  64  145   81  6.30
# 33  145Eu  -77.936   5/2+  63  145   82  6.30
# 34  146Gd  -75.361     0+  64  146   82  6.32
# 35  209Bi  -18.268   9/2−  83  209  126  7.12
# 36  209Pb  -17.624   9/2+  82  209  127  7.12
# 37  207Pb  -22.463   1/2−  82  207  125  7.10
# 38  207Tl  -21.041   1/2+  81  207  126  7.10
# 39  208Pb  -21.759     0+  82  208  126  7.11

# %% [markdown]
# Una vez creada la base de datos, podemos crear la función energía_nivel(Nucleos) que nos devolverá una tabla con todos los datos que queremos (Energías superior e inferior de fermi para protones y neutrones de cada isótopo)

# %%
############## DEFINITIVO ###################

def energia_nivel(Nucleos, Deltaneutron=8.071, Deltaproton=7.288):
    
    data = {
        'E_F superior (neutron)': [],
        'E_F inferior (neutron)': [],
        'E_F superior (proton)': [],
        'E_F inferior (proton)': []
    }

    for nucleo in Nucleos:

        # Obtener N y Z del núcleo actual
        N = df.loc[df['Núcleo'] == nucleo, 'N'].values[0]
        Z = df.loc[df['Núcleo'] == nucleo, 'Z'].values[0]

        # Energía del nivel actual
        e_nivel = df.loc[df['Núcleo'] == nucleo, 'Δ (MeV)'].values[0]

        # Niveles de neutrones
        try:
            neutron_posterior = df.loc[(df['N'] == N+1) & (df['Z'] == Z), 'Núcleo'].values[0]
            e_posterior_neutron = df.loc[df['Núcleo'] == neutron_posterior, 'Δ (MeV)'].values[0]
            energia_superior_neutron = e_posterior_neutron - e_nivel - Deltaneutron
        except IndexError:
            energia_superior_neutron = None  # Si no hay datos

        try:
            neutron_anterior = df.loc[(df['N'] == N-1) & (df['Z'] == Z), 'Núcleo'].values[0]
            e_anterior_neutron = df.loc[df['Núcleo'] == neutron_anterior, 'Δ (MeV)'].values[0]
            energia_inferior_neutron = e_nivel - e_anterior_neutron - Deltaneutron
        except IndexError:
            energia_inferior_neutron = None

        # Niveles de protones
        try:
            proton_posterior = df.loc[(df['Z'] == Z+1) & (df['N'] == N), 'Núcleo'].values[0]
            e_posterior_proton = df.loc[df['Núcleo'] == proton_posterior, 'Δ (MeV)'].values[0]
            energia_superior_proton = e_posterior_proton - e_nivel - Deltaproton
        except IndexError:
            energia_superior_proton = None

        try:
            proton_anterior = df.loc[(df['Z'] == Z-1) & (df['N'] == N), 'Núcleo'].values[0]
            e_anterior_proton = df.loc[df['Núcleo'] == proton_anterior, 'Δ (MeV)'].values[0]
            energia_inferior_proton = e_nivel - e_anterior_proton - Deltaproton
        except IndexError:
            energia_inferior_proton = None

        # Almacenar los resultados en listas correspondientes
        data['E_F superior (neutron)'].append(energia_superior_neutron)
        data['E_F inferior (neutron)'].append(energia_inferior_neutron)
        data['E_F superior (proton)'].append(energia_superior_proton)
        data['E_F inferior (proton)'].append(energia_inferior_proton)

    # Convertir el diccionario en DataFrame y establecer Nucleos como columnas
    tabla = pd.DataFrame(data, index=Nucleos).T  # Usar .T para transponer y hacer de Nucleos las columnas

    return tabla

# %% [markdown]
# Para los núcleos que nos ocupan:

# %%
magicos = ['12C', '16O', '40Ca', '48Ca']

Niveles_nucleos = energia_nivel(Nucleos=magicos)

# %% [markdown]
# Vamos a añadirle a cada isótopo sus estados:

# %%
# Valores para los nuevos orbitales
orbital_sup_prot = {
    '12C': [1, 1, 1, 1, 1],
    '16O': [1, 1, 1, 2, 3],
    '40Ca': [1, 1, 1, 3, 4],
    '48Ca': [1, 1, 1, 3, 4]
}

orbital_inf_prot = {
    '12C': [0, 1, 1, 1, 2],
    '16O': [0, 1, 1, 1, 2],
    '40Ca': [0, 1, 1, 2, 2],
    '48Ca': [0, 1, 1, 2, 2]
}

orbital_sup_neut = {
    '12C': [1, 0, 1, 1, 1],
    '16O': [1, 0, 1, 2, 3],
    '40Ca': [1, 0, 1, 3, 4],
    '48Ca': [0, 0, 1, 3, 4]
}

orbital_inf_neut = {
    '12C': [0, 0, 1, 1, 2],
    '16O': [0, 0, 1, 1, 2],
    '40Ca': [0, 0, 1, 2, 2],
    '48Ca': [1, 1, 2, 1, 2]
}

# Añadir nuevas columnas al DataFrame
Niveles_nucleos.loc['orbital_sup_prot'] = [orbital_sup_prot['12C'], orbital_sup_prot['16O'], orbital_sup_prot['40Ca'], orbital_sup_prot['48Ca']]
Niveles_nucleos.loc['orbital_inf_prot'] = [orbital_inf_prot['12C'], orbital_inf_prot['16O'], orbital_inf_prot['40Ca'], orbital_inf_prot['48Ca']]
Niveles_nucleos.loc['orbital_sup_neut'] = [orbital_sup_neut['12C'], orbital_sup_neut['16O'], orbital_sup_neut['40Ca'], orbital_sup_neut['48Ca']]
Niveles_nucleos.loc['orbital_inf_neut'] = [orbital_inf_neut['12C'], orbital_inf_neut['16O'], orbital_inf_neut['40Ca'], orbital_inf_neut['48Ca']]

# Mostrar el DataFrame actualizado
Niveles_nucleos.head(8)
# Out:
#                                     12C              16O             40Ca  \
# E_F superior (neutron)           -4.946           -4.144           -8.363
# E_F inferior (neutron)          -18.721          -15.663          -15.636
# E_F superior (proton)            -1.852           -0.599           -1.085
# E_F inferior (proton)           -15.956          -12.127           -8.329
# orbital_sup_prot        [1, 1, 1, 1, 1]  [1, 1, 1, 2, 3]  [1, 1, 1, 3, 4]
# orbital_inf_prot        [0, 1, 1, 1, 2]  [0, 1, 1, 1, 2]  [0, 1, 1, 2, 2]
# orbital_sup_neut        [1, 0, 1, 1, 1]  [1, 0, 1, 2, 3]  [1, 0, 1, 3, 4]
# orbital_inf_neut        [0, 0, 1, 1, 2]  [0, 0, 1, 1, 2]  [0, 0, 1, 2, 2]
#
#                                    48Ca
# E_F superior (neutron)           -5.141
# E_F inferior (neutron)           -9.944
# E_F superior (proton)            -9.627
# E_F inferior (proton)           -15.806
# orbital_sup_prot        [1, 1, 1, 3, 4]
# orbital_inf_prot        [0, 1, 1, 2, 2]
# orbital_sup_neut        [0, 0, 1, 3, 4]
# orbital_inf_neut        [1, 1, 2, 1, 2]

# %% [markdown]
# Vamos a crear una serie de funciones para automatizar la minimización de valores de $V_0$ y $V_{LS}$ para cada núcleo

# %%
import subprocess
import os
import re

# %% [markdown]
# Lo primero es introducir el path en el que estamos trabajando (la carpeta en la que tengamos el wsmod_W.exe).

# %%
os.chdir('C:\\Users\\migue\\Desktop\\WS\\WS_modificado')

# %%
Ca40 = '40Ca'
C12 = '12C'
O16 = '16O'
Ca48 = '48Ca'

# %%
# Llamamos "comando" al comando que usaríamos en terminal para crear los
# ficheros que hemos definido en la celda anterior. 

def comando(nucleo):
    comando = "wsmod_W.exe < wsnum.inp >" + ' ' + nucleo + '.txt'
    return comando

filas = 4   ## El número de filas a partir del cuál empiezan los valores de
            ## Energía n'el fichero

## Corremos el proceso que queremos en terminal.

def proceso(nucleo):
    proceso = subprocess.run(comando(nucleo), shell=True, capture_output=True, text=True)
    data_P = pd.read_csv(nucleo + '.txt', header = filas)                                   ##header viendo donde empezamos a contar
    return data_P

# %% [markdown]
# Por poner un ejemplo para ver cómo se vería el Calcio:

# %%
print(proceso(Ca40))
# Out:
#    NR. PROTON STATES=  7  NR. NEUTRON STATES= 10
# 0                          0  1  1  0  1 -33.700
# 1                          0  1  1  1  2 -23.946
# 2                          0  1  1  1  1 -21.701
# 3                          0  1  1  2  3 -13.169
# 4                          0  1  2  0  1  -8.552
# 5                          0  1  1  2  2  -8.397
# 6                          1  1  1  3  4  -1.819
# 7                          0  0  1  0  1 -47.238
# 8                          0  0  1  1  1 -36.706
# 9                          0  0  1  1  2 -35.459
# 10                         0  0  1  2  2 -24.620
# 11                         0  0  1  2  3 -21.917
# 12                         0  0  2  0  1 -20.144
# 13                         1  0  1  3  3 -11.707
# 14                         1  0  2  1  1  -7.635
# 15                         1  0  1  3  4  -7.349
# 16                         1  0  2  1  2  -6.291

# %% [markdown]
# Ahora, creamos la función sacar energía, que nos devuelva las energías superior e inferior del fichero.

# %%
def sacar_energia(nucleo, pn): ## PN es 0 para neutrones 1 para protones.

    data = proceso(nucleo)

    ## Cogemos los valores correspondientes.

    if pn == 0:
        estado_inferior_inp = Niveles_nucleos[nucleo]['orbital_inf_neut']
        estado_superior_inp = Niveles_nucleos[nucleo]['orbital_sup_neut']

    else:
        estado_inferior_inp = Niveles_nucleos[nucleo]['orbital_inf_prot']
        estado_superior_inp = Niveles_nucleos[nucleo]['orbital_sup_prot']

    ## Transformamos los datos a listas de enteros.

    ## inicializamos el array

    datos_transf = np.zeros((len(data),6))

    ## Transformamos los datos

    for i in range(len(data)):

        ## Los convertimos fila a fila en una lista de enteros
        datos_transf[i] = [float(num) for num in data.values[i][0].split()]

        ## Consideramos para evaluar el estado hueco/part , proton/neutron , n , l , j+12
        estado_i = datos_transf[i][:5]

        if np.all(estado_i == estado_inferior_inp):
            energia_inferior = datos_transf[i,-1]

        if np.all(estado_i == estado_superior_inp):
            energia_superior = datos_transf[i,-1]    


    return np.array([energia_inferior,energia_superior])

# %% [markdown]
# Ahora creamos una función que nos permita modificar el fichero.

# %%
## CAMBIAR EL PATH SEGÚN DÓNDE LO TENGAS ##
camino = 'C:\\Users\\migue\\Desktop\\WS\\WS_modificado\\wsnum.inp'


def modificar_isotopo(file_path,nucleo,tipo):

    # Leer el contenido del archivo
    with open(file_path, 'r') as file:
        lineas = file.readlines()

    # Separar elementos
    elementos_separados = []
    for linea in lineas:
        elementos = linea.strip().split()
        elementos_separados.extend(elementos)

    ## Modificar A,Z
        ## A

    A = df.loc[df['Núcleo'] == nucleo, 'A'].values[0]
    elementos_separados[3] = str(A)

        ## Z

    Z = df.loc[df['Núcleo'] == nucleo, 'Z'].values[0]
    elementos_separados[4] = str(Z)

    ## Modificar Radio

    if tipo == 1:
        elementos_separados[14] = str(df.loc[df['Núcleo'] == nucleo, 'R'].values[0])
        elementos_separados[17] = str(df.loc[df['Núcleo'] == nucleo, 'R'].values[0])
        elementos_separados[19] = str(df.loc[df['Núcleo'] == nucleo, 'R'].values[0])

    else:
        elementos_separados[21] = str(df.loc[df['Núcleo'] == nucleo, 'R'].values[0])
        elementos_separados[24] = str(df.loc[df['Núcleo'] == nucleo, 'R'].values[0])
        elementos_separados[26] = str(0)
    
    # Volver a escribir el archivo manteniendo el formato original
    with open(file_path, 'w') as file:
        # Inicializar un índice para ir agregando los elementos a las líneas
        indice = 0

        for linea in lineas:
            # Limpiar la línea y obtener la cantidad de elementos en la línea original
            elementos_linea = linea.strip().split()

            # Crear una nueva línea con los elementos modificados
            nueva_linea = []
            for _ in elementos_linea:
                if indice < len(elementos_separados):
                    nueva_linea.append(elementos_separados[indice])
                    indice += 1

            # Unir los elementos de la nueva línea y escribir
            file.write('   '.join(nueva_linea) + '\n')


def modificar_v(file_path, tipo, nuevo_v0, nuevo_vls):
    # Leer el contenido del archivo
    with open(file_path, 'r') as file:
        lineas = file.readlines()

    # Separar elementos
    elementos_separados = []
    for linea in lineas:
        elementos = linea.strip().split()
        elementos_separados.extend(elementos)
    
    if tipo==1:

        # Modificar V0 y VLS
        elementos_separados[13] = str(nuevo_v0)  # Cambiar V0 (elemento 13)
        elementos_separados[16] = str(nuevo_vls)  # Cambiar VLS (elemento 16)

    else: 
        
        # Modificar V0 y VLS
        elementos_separados[20] = str(nuevo_v0) 
        elementos_separados[23] = str(nuevo_vls) 
        

    # Volver a escribir el archivo manteniendo el formato original
    with open(file_path, 'w') as file:
        # Inicializar un índice para ir agregando los elementos a las líneas
        indice = 0

        for linea in lineas:
            # Limpiar la línea y obtener la cantidad de elementos en la línea original
            elementos_linea = linea.strip().split()

            # Crear una nueva línea con los elementos modificados
            nueva_linea = []
            for _ in elementos_linea:
                if indice < len(elementos_separados):
                    nueva_linea.append(elementos_separados[indice])
                    indice += 1

            # Unir los elementos de la nueva línea y escribir
            file.write('   '.join(nueva_linea) + '\n')

# %%
## Función para automatizar el cambio en los valores de V0, VLS y sacar energía:

def ENERGIA(nucleo,pn,V0,VLS,camino = 'C:\\Users\\migue\\Desktop\\WS\\WS_modificado\\wsnum.inp'):
    modificar_v(file_path=camino, tipo=pn, nuevo_v0=V0, nuevo_vls=VLS)
    output = sacar_energia(nucleo = nucleo, pn=pn)
    return output

# %% [markdown]
# Creamos una función para minimizar los parámetros v0 y vls

# %%
def f_min(nucleo,tipo, V0, VLS, f=ENERGIA):

    if tipo == 0:
        valores_teo = [Niveles_nucleos[nucleo]['E_F inferior (neutron)'] , Niveles_nucleos[nucleo]['E_F superior (neutron)']]
    else:
        valores_teo = [Niveles_nucleos[nucleo]['E_F inferior (proton)'] , Niveles_nucleos[nucleo]['E_F superior (proton)']]
    return np.array([abs(valores_teo[0] - f(nucleo, tipo, V0, VLS)[0]), 
                     abs(valores_teo[1] - f(nucleo, tipo ,V0, VLS)[1])])

# %% [markdown]
# Y ahora lo importante: Creamos una función que nos permita minimizar la función anterior, de forma que, iterativamente, calcule el valor óptimo de V0 y VLS

# %%
## Jacobian calculation for a vector-valued function
def jacobian(nucleo,tipo,V0, VLS, h=1e-2, f=f_min):
    J = np.zeros((2, 2))  # Jacobian matrix (2x2)
    
    # Partial derivatives for f1 (component 1 of f)
    J[0, 0] = (f(nucleo,tipo,V0+h, VLS)[0] - f(nucleo,tipo,V0, VLS)[0]) / h  # df1/dV0
    J[0, 1] = (f(nucleo,tipo,V0, VLS+h)[0] - f(nucleo,tipo,V0, VLS)[0]) / h  # df1/dVLS
    
    # Partial derivatives for f2 (component 2 of f)
    J[1, 0] = (f(nucleo,tipo,V0+h, VLS)[1] - f(nucleo,tipo,V0, VLS)[1]) / h  # df2/dV0
    J[1, 1] = (f(nucleo,tipo,V0, VLS+h)[1] - f(nucleo,tipo,V0, VLS)[1]) / h  # df2/dVLS

    return J

def jacobian_gradient_descent(nucleo,tipo,eta1,eta2,tolerancia,max_iter,v0,vls): ## V0, VLS Son los valores iniciales con los que empezamos a iterar.

    ## Bucle de Gradient Descent:
    for i in range(max_iter):
    ## Jacobiano en la posición actual
        J = jacobian(nucleo,tipo,v0, vls)

    ## Valor de la función f en la posición actual
        f_val = f_min(nucleo,tipo,v0, vls)

    ## Imprime los valores de f_min y el Jacobiano para debug
        print(f"Iteración {i}: f_min = {f_val}, Jacobiano = \n{J}")

    ## Calcular el gradiente (dirección negativa de los valores de la función)
        gradient = -J.T @ f_val  # Producto del Jacobiano transpuesto por el valor de f_min

    ## Imprimir el gradiente para ver si es muy grande
        print(f"Gradiente = {gradient}")
        print(f'Energías: inferior = {round(f_val[0],3)}, superior = {round(f_val[1],3)}')
    

    ## Actualización de las variables
        v0_new = v0 + eta1 * gradient[0]
        vls_new = vls + eta2 * gradient[1]

        if round(f_min(nucleo,tipo,v0_new,vls_new)[0],3) <= tolerancia and round(f_min(nucleo,tipo,v0_new,vls_new)[1],3) <= tolerancia:
            print(f"Converged after {i} iterations.")
            break

    ## Actualizar variables para la siguiente iteración
        v0, vls = v0_new, vls_new

        print(f"v0 = {v0}, vls = {vls}, Iteración = {i}")


    v0, vls = v0_new, vls_new

    print(f'Minimum found at:\n V_0 = {v0}, V_LS = {vls}')

# %% [markdown]
# # $^{40}Ca$

# %% [markdown]
# ## Protones

# %%
modificar_isotopo(camino,Ca40,tipo=1)

jacobian_gradient_descent(nucleo=Ca40,tipo=1,eta1=5e-2,eta2=5e-2,tolerancia=3e-3,max_iter=10000,v0=-55.0,vls=-7.0)
# Out:
# Iteración 0: f_min = [0.068 0.734], Jacobiano =
# [[-0.7  0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.488  0.2664]
# Energías: inferior = 0.068, superior = 0.734
# v0 = -54.9756, vls = -6.98668, Iteración = 0
# Iteración 1: f_min = [0.055 0.713], Jacobiano =
# [[-0.8  0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.4718 0.2632]
# Energías: inferior = 0.055, superior = 0.713
# v0 = -54.95201, vls = -6.97352, Iteración = 1
# Iteración 2: f_min = [0.042 0.692], Jacobiano =
# [[-0.7  0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.4446 0.26  ]
# Energías: inferior = 0.042, superior = 0.692
# v0 = -54.92978, vls = -6.96052, Iteración = 2
# Iteración 3: f_min = [0.031 0.673], Jacobiano =
# [[-0.8  0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.4959 0.3241]
# Energías: inferior = 0.031, superior = 0.673
# v0 = -54.904985, vls = -6.944315, Iteración = 3
# Iteración 4: f_min = [0.018 0.65 ], Jacobiano =
# [[-0.7  0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.4026 0.3178]
# Energías: inferior = 0.018, superior = 0.65
# v0 = -54.884855, vls = -6.928424999999999, Iteración = 4
# Iteración 5: f_min = [0.009 0.63 ], Jacobiano =
# [[-0.7  0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.3843 0.3114]
# Energías: inferior = 0.009, superior = 0.63
# v0 = -54.86564, vls = -6.912854999999999, Iteración = 5
# Iteración 6: f_min = [0.001 0.611], Jacobiano =
# [[ 0.6  0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.366  0.3051]
# Energías: inferior = 0.001, superior = 0.611
# v0 = -54.847339999999996, vls = -6.897599999999999, Iteración = 6
# Iteración 7: f_min = [0.007 0.593], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.4095 0.2993]
# Energías: inferior = 0.007, superior = 0.593
# v0 = -54.826865, vls = -6.882634999999999, Iteración = 7
# Iteración 8: f_min = [0.017 0.573], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.3319 0.2933]
# Energías: inferior = 0.017, superior = 0.573
# v0 = -54.810269999999996, vls = -6.867969999999999, Iteración = 8
# Iteración 9: f_min = [0.023 0.556], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.3152 0.2872]
# Energías: inferior = 0.023, superior = 0.556
# v0 = -54.794509999999995, vls = -6.853609999999998, Iteración = 9
# Iteración 10: f_min = [0.03 0.54], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.357 0.282]
# Energías: inferior = 0.03, superior = 0.54
# v0 = -54.77665999999999, vls = -6.839509999999998, Iteración = 10
# Iteración 11: f_min = [0.038 0.522], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.2866 0.2762]
# Energías: inferior = 0.038, superior = 0.522
# v0 = -54.76232999999999, vls = -6.8256999999999985, Iteración = 11
# Iteración 12: f_min = [0.043 0.507], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.2698 0.2707]
# Energías: inferior = 0.043, superior = 0.507
# v0 = -54.748839999999994, vls = -6.8121649999999985, Iteración = 12
# Iteración 13: f_min = [0.048 0.492], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.2568 0.216 ]
# Energías: inferior = 0.048, superior = 0.492
# v0 = -54.736, vls = -6.801364999999999, Iteración = 13
# Iteración 14: f_min = [0.053 0.479], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.245  0.2128]
# Energías: inferior = 0.053, superior = 0.479
# v0 = -54.723749999999995, vls = -6.790724999999998, Iteración = 14
# Iteración 15: f_min = [0.058 0.467], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.2338 0.2567]
# Energías: inferior = 0.058, superior = 0.467
# v0 = -54.712059999999994, vls = -6.777889999999998, Iteración = 15
# Iteración 16: f_min = [0.062 0.454], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.2682 0.2518]
# Energías: inferior = 0.062, superior = 0.454
# v0 = -54.698649999999994, vls = -6.765299999999998, Iteración = 16
# Iteración 17: f_min = [0.067 0.44 ], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.2544 0.2468]
# Energías: inferior = 0.067, superior = 0.44
# v0 = -54.68592999999999, vls = -6.752959999999998, Iteración = 17
# Iteración 18: f_min = [0.072 0.426], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.198  0.2418]
# Energías: inferior = 0.072, superior = 0.426
# v0 = -54.67602999999999, vls = -6.740869999999998, Iteración = 18
# Iteración 19: f_min = [0.075 0.414], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.1959 0.1956]
# Energías: inferior = 0.075, superior = 0.414
# v0 = -54.66623499999999, vls = -6.731089999999998, Iteración = 19
# Iteración 20: f_min = [0.078 0.404], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.18   0.2332]
# Energías: inferior = 0.078, superior = 0.404
# v0 = -54.65723499999999, vls = -6.719429999999997, Iteración = 20
# Iteración 21: f_min = [0.081 0.393], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.1791 0.2289]
# Energías: inferior = 0.081, superior = 0.393
# v0 = -54.64827999999999, vls = -6.707984999999997, Iteración = 21
# Iteración 22: f_min = [0.083 0.382], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.1711 0.2242]
# Energías: inferior = 0.083, superior = 0.382
# v0 = -54.63972499999999, vls = -6.696774999999997, Iteración = 22
# Iteración 23: f_min = [0.085 0.372], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.2009 0.22  ]
# Energías: inferior = 0.085, superior = 0.372
# v0 = -54.62967999999999, vls = -6.685774999999997, Iteración = 23
# Iteración 24: f_min = [0.088 0.36 ], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.1456 0.1792]
# Energías: inferior = 0.088, superior = 0.36
# v0 = -54.62239999999999, vls = -6.676814999999997, Iteración = 24
# Iteración 25: f_min = [0.09  0.352], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.1744 0.212 ]
# Energías: inferior = 0.09, superior = 0.352
# v0 = -54.613679999999995, vls = -6.666214999999997, Iteración = 25
# Iteración 26: f_min = [0.092 0.341], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.131  0.1732]
# Energías: inferior = 0.092, superior = 0.341
# v0 = -54.60713, vls = -6.657554999999997, Iteración = 26
# Iteración 27: f_min = [0.094 0.333], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.134  0.1708]
# Energías: inferior = 0.094, superior = 0.333
# v0 = -54.600429999999996, vls = -6.649014999999996, Iteración = 27
# Iteración 28: f_min = [0.096 0.325], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.1278 0.1684]
# Energías: inferior = 0.096, superior = 0.325
# v0 = -54.59403999999999, vls = -6.640594999999996, Iteración = 28
# Iteración 29: f_min = [0.097 0.317], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.1126 0.1656]
# Energías: inferior = 0.097, superior = 0.317
# v0 = -54.58840999999999, vls = -6.632314999999995, Iteración = 29
# Iteración 30: f_min = [0.098 0.31 ], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.1076 0.1942]
# Energías: inferior = 0.098, superior = 0.31
# v0 = -54.58302999999999, vls = -6.622604999999995, Iteración = 30
# Iteración 31: f_min = [0.098 0.302], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.1028 0.16  ]
# Energías: inferior = 0.098, superior = 0.302
# v0 = -54.57788999999999, vls = -6.614604999999995, Iteración = 31
# Iteración 32: f_min = [0.099 0.295], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0978 0.1576]
# Energías: inferior = 0.099, superior = 0.295
# v0 = -54.57299999999999, vls = -6.606724999999995, Iteración = 32
# Iteración 33: f_min = [0.1   0.289], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.1034 0.1845]
# Energías: inferior = 0.1, superior = 0.289
# v0 = -54.567829999999994, vls = -6.597499999999994, Iteración = 33
# Iteración 34: f_min = [0.1   0.281], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0986 0.1524]
# Energías: inferior = 0.1, superior = 0.281
# v0 = -54.56289999999999, vls = -6.589879999999993, Iteración = 34
# Iteración 35: f_min = [0.1   0.275], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.085  0.1775]
# Energías: inferior = 0.1, superior = 0.275
# v0 = -54.55864999999999, vls = -6.581004999999992, Iteración = 35
# Iteración 36: f_min = [0.1   0.268], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0808 0.174 ]
# Energías: inferior = 0.1, superior = 0.268
# v0 = -54.55460999999999, vls = -6.572304999999991, Iteración = 36
# Iteración 37: f_min = [0.1   0.262], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.1134 0.171 ]
# Energías: inferior = 0.1, superior = 0.262
# v0 = -54.54893999999999, vls = -6.563754999999991, Iteración = 37
# Iteración 38: f_min = [0.101 0.254], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0817 0.1674]
# Energías: inferior = 0.101, superior = 0.254
# v0 = -54.544854999999984, vls = -6.5553849999999905, Iteración = 38
# Iteración 39: f_min = [0.1   0.248], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0688 0.164 ]
# Energías: inferior = 0.1, superior = 0.248
# v0 = -54.541414999999986, vls = -6.54718499999999, Iteración = 39
# Iteración 40: f_min = [0.1   0.242], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0752 0.161 ]
# Energías: inferior = 0.1, superior = 0.242
# v0 = -54.53765499999999, vls = -6.539134999999989, Iteración = 40
# Iteración 41: f_min = [0.099 0.236], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0624 0.1576]
# Energías: inferior = 0.099, superior = 0.236
# v0 = -54.534534999999984, vls = -6.531254999999989, Iteración = 41
# Iteración 42: f_min = [0.099 0.23 ], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0687 0.1316]
# Energías: inferior = 0.099, superior = 0.23
# v0 = -54.53109999999998, vls = -6.52467499999999, Iteración = 42
# Iteración 43: f_min = [0.099 0.225], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0657 0.1521]
# Energías: inferior = 0.099, superior = 0.225
# v0 = -54.52781499999998, vls = -6.51706999999999, Iteración = 43
# Iteración 44: f_min = [0.098 0.22 ], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0756 0.1492]
# Energías: inferior = 0.098, superior = 0.22
# v0 = -54.524034999999984, vls = -6.50960999999999, Iteración = 44
# Iteración 45: f_min = [0.098 0.214], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0598 0.1462]
# Energías: inferior = 0.098, superior = 0.214
# v0 = -54.52104499999999, vls = -6.50229999999999, Iteración = 45
# Iteración 46: f_min = [0.097 0.209], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0687 0.1433]
# Energías: inferior = 0.097, superior = 0.209
# v0 = -54.51760999999998, vls = -6.49513499999999, Iteración = 46
# Iteración 47: f_min = [0.097 0.203], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0442 0.12  ]
# Energías: inferior = 0.097, superior = 0.203
# v0 = -54.515399999999985, vls = -6.4891349999999886, Iteración = 47
# Iteración 48: f_min = [0.096 0.199], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0426 0.1379]
# Energías: inferior = 0.096, superior = 0.199
# v0 = -54.513269999999984, vls = -6.4822399999999885, Iteración = 48
# Iteración 49: f_min = [0.095 0.195], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0605 0.1355]
# Energías: inferior = 0.095, superior = 0.195
# v0 = -54.51024499999998, vls = -6.475464999999988, Iteración = 49
# Iteración 50: f_min = [0.095 0.19 ], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0665 0.133 ]
# Energías: inferior = 0.095, superior = 0.19
# v0 = -54.50691999999999, vls = -6.468814999999989, Iteración = 50
# Iteración 51: f_min = [0.095 0.184], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0439 0.1116]
# Energías: inferior = 0.095, superior = 0.184
# v0 = -54.504724999999986, vls = -6.4632349999999885, Iteración = 51
# Iteración 52: f_min = [0.094 0.18 ], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0328 0.1096]
# Energías: inferior = 0.094, superior = 0.18
# v0 = -54.503084999999984, vls = -6.457754999999988, Iteración = 52
# Iteración 53: f_min = [0.093 0.177], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0318 0.1257]
# Energías: inferior = 0.093, superior = 0.177
# v0 = -54.501494999999984, vls = -6.451469999999988, Iteración = 53
# Iteración 54: f_min = [0.092 0.173], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0394 0.1233]
# Energías: inferior = 0.092, superior = 0.173
# v0 = -54.499524999999984, vls = -6.445304999999988, Iteración = 54
# Iteración 55: f_min = [0.091 0.169], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0377 0.1209]
# Energías: inferior = 0.091, superior = 0.169
# v0 = -54.49763999999998, vls = -6.4392599999999875, Iteración = 55
# Iteración 56: f_min = [0.09  0.165], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.036  0.1185]
# Energías: inferior = 0.09, superior = 0.165
# v0 = -54.49583999999999, vls = -6.433334999999988, Iteración = 56
# Iteración 57: f_min = [0.089 0.161], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0343 0.1   ]
# Energías: inferior = 0.089, superior = 0.161
# v0 = -54.49412499999999, vls = -6.428334999999988, Iteración = 57
# Iteración 58: f_min = [0.088 0.158], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0244 0.1142]
# Energías: inferior = 0.088, superior = 0.158
# v0 = -54.492904999999986, vls = -6.4226249999999885, Iteración = 58
# Iteración 59: f_min = [0.087 0.154], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0315 0.0964]
# Energías: inferior = 0.087, superior = 0.154
# v0 = -54.491329999999984, vls = -6.417804999999989, Iteración = 59
# Iteración 60: f_min = [0.086 0.151], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0218 0.0948]
# Energías: inferior = 0.086, superior = 0.151
# v0 = -54.490239999999986, vls = -6.413064999999989, Iteración = 60
# Iteración 61: f_min = [0.085 0.148], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0293 0.0932]
# Energías: inferior = 0.085, superior = 0.148
# v0 = -54.48877499999998, vls = -6.408404999999989, Iteración = 61
# Iteración 62: f_min = [0.084 0.145], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0198 0.0916]
# Energías: inferior = 0.084, superior = 0.145
# v0 = -54.48778499999998, vls = -6.403824999999988, Iteración = 62
# Iteración 63: f_min = [0.083 0.143], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0194 0.1047]
# Energías: inferior = 0.083, superior = 0.143
# v0 = -54.48681499999998, vls = -6.398589999999988, Iteración = 63
# Iteración 64: f_min = [0.082 0.14 ], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0406 0.1028]
# Energías: inferior = 0.082, superior = 0.14
# v0 = -54.48478499999998, vls = -6.393449999999988, Iteración = 64
# Iteración 65: f_min = [0.081 0.136], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0168 0.1004]
# Energías: inferior = 0.081, superior = 0.136
# v0 = -54.48394499999998, vls = -6.388429999999987, Iteración = 65
# Iteración 66: f_min = [0.08  0.133], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0238 0.0852]
# Energías: inferior = 0.08, superior = 0.133
# v0 = -54.482754999999976, vls = -6.384169999999987, Iteración = 66
# Iteración 67: f_min = [0.079 0.13 ], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0148 0.0836]
# Energías: inferior = 0.079, superior = 0.13
# v0 = -54.482014999999976, vls = -6.379989999999987, Iteración = 67
# Iteración 68: f_min = [0.078 0.128], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0222 0.0952]
# Energías: inferior = 0.078, superior = 0.128
# v0 = -54.48090499999998, vls = -6.375229999999986, Iteración = 68
# Iteración 69: f_min = [0.077 0.125], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0211 0.0808]
# Energías: inferior = 0.077, superior = 0.125
# v0 = -54.47984999999998, vls = -6.371189999999986, Iteración = 69
# Iteración 70: f_min = [0.076 0.123], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.013  0.0919]
# Energías: inferior = 0.076, superior = 0.123
# v0 = -54.47919999999998, vls = -6.366594999999986, Iteración = 70
# Iteración 71: f_min = [0.075 0.12 ], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0195 0.078 ]
# Energías: inferior = 0.075, superior = 0.12
# v0 = -54.47822499999998, vls = -6.362694999999986, Iteración = 71
# Iteración 72: f_min = [0.074 0.118], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.019  0.0886]
# Energías: inferior = 0.074, superior = 0.118
# v0 = -54.477274999999985, vls = -6.358264999999986, Iteración = 72
# Iteración 73: f_min = [0.073 0.115], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0179 0.0752]
# Energías: inferior = 0.073, superior = 0.115
# v0 = -54.476379999999985, vls = -6.354504999999986, Iteración = 73
# Iteración 74: f_min = [0.072 0.113], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0102 0.0853]
# Energías: inferior = 0.072, superior = 0.113
# v0 = -54.475869999999986, vls = -6.350239999999986, Iteración = 74
# Iteración 75: f_min = [0.071 0.111], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.028  0.0839]
# Energías: inferior = 0.071, superior = 0.111
# v0 = -54.47446999999999, vls = -6.346044999999986, Iteración = 75
# Iteración 76: f_min = [0.07  0.108], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0088 0.082 ]
# Energías: inferior = 0.07, superior = 0.108
# v0 = -54.47402999999999, vls = -6.341944999999986, Iteración = 76
# Iteración 77: f_min = [0.069 0.106], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0259 0.0806]
# Energías: inferior = 0.069, superior = 0.106
# v0 = -54.47273499999999, vls = -6.3379149999999855, Iteración = 77
# Iteración 78: f_min = [0.068 0.103], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0074 0.0787]
# Energías: inferior = 0.068, superior = 0.103
# v0 = -54.472364999999996, vls = -6.333979999999985, Iteración = 78
# Iteración 79: f_min = [0.067 0.101], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0137 0.0773]
# Energías: inferior = 0.067, superior = 0.101
# v0 = -54.47168, vls = -6.330114999999985, Iteración = 79
# Iteración 80: f_min = [0.066 0.099], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0132 0.0759]
# Energías: inferior = 0.066, superior = 0.099
# v0 = -54.471019999999996, vls = -6.326319999999985, Iteración = 80
# Iteración 81: f_min = [0.065 0.097], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0224 0.0745]
# Energías: inferior = 0.065, superior = 0.097
# v0 = -54.469899999999996, vls = -6.322594999999985, Iteración = 81
# Iteración 82: f_min = [0.064 0.094], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0052 0.0632]
# Energías: inferior = 0.064, superior = 0.094
# v0 = -54.46964, vls = -6.319434999999984, Iteración = 82
# Iteración 83: f_min = [0.063 0.093], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0147 0.0717]
# Energías: inferior = 0.063, superior = 0.093
# v0 = -54.468905, vls = -6.315849999999984, Iteración = 83
# Iteración 84: f_min = [0.062 0.09 ], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0044 0.0608]
# Energías: inferior = 0.062, superior = 0.09
# v0 = -54.468685, vls = -6.312809999999984, Iteración = 84
# Iteración 85: f_min = [0.061 0.089], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0046 0.0689]
# Energías: inferior = 0.061, superior = 0.089
# v0 = -54.468455, vls = -6.309364999999984, Iteración = 85
# Iteración 86: f_min = [0.06  0.087], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0042 0.0588]
# Energías: inferior = 0.06, superior = 0.087
# v0 = -54.468244999999996, vls = -6.306424999999984, Iteración = 86
# Iteración 87: f_min = [0.059 0.086], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0103 0.0666]
# Energías: inferior = 0.059, superior = 0.086
# v0 = -54.467729999999996, vls = -6.303094999999984, Iteración = 87
# Iteración 88: f_min = [0.058 0.084], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.004  0.0652]
# Energías: inferior = 0.058, superior = 0.084
# v0 = -54.46753, vls = -6.299834999999984, Iteración = 88
# Iteración 89: f_min = [0.057 0.082], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0093 0.0556]
# Energías: inferior = 0.057, superior = 0.082
# v0 = -54.467065, vls = -6.297054999999983, Iteración = 89
# Iteración 90: f_min = [0.056 0.081], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0038 0.0629]
# Energías: inferior = 0.056, superior = 0.081
# v0 = -54.466874999999995, vls = -6.2939099999999835, Iteración = 90
# Iteración 91: f_min = [0.055 0.079], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0034 0.0615]
# Energías: inferior = 0.055, superior = 0.079
# v0 = -54.466705, vls = -6.290834999999983, Iteración = 91
# Iteración 92: f_min = [0.054 0.078], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0168 0.0606]
# Energías: inferior = 0.054, superior = 0.078
# v0 = -54.465865, vls = -6.287804999999983, Iteración = 92
# Iteración 93: f_min = [0.053 0.076], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0108 0.0592]
# Energías: inferior = 0.053, superior = 0.076
# v0 = -54.465325, vls = -6.284844999999983, Iteración = 93
# Iteración 94: f_min = [0.052 0.074], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0028 0.0578]
# Energías: inferior = 0.052, superior = 0.074
# v0 = -54.465185, vls = -6.281954999999982, Iteración = 94
# Iteración 95: f_min = [0.051 0.073], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0103 0.0569]
# Energías: inferior = 0.051, superior = 0.073
# v0 = -54.46467, vls = -6.279109999999982, Iteración = 95
# Iteración 96: f_min = [0.051 0.071], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0069 0.0559]
# Energías: inferior = 0.051, superior = 0.071
# v0 = -54.464324999999995, vls = -6.2763149999999825, Iteración = 96
# Iteración 97: f_min = [0.05  0.069], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0064 0.0476]
# Energías: inferior = 0.05, superior = 0.069
# v0 = -54.46400499999999, vls = -6.273934999999983, Iteración = 97
# Iteración 98: f_min = [0.049 0.068], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0016 0.0536]
# Energías: inferior = 0.049, superior = 0.068
# v0 = -54.463924999999996, vls = -6.271254999999982, Iteración = 98
# Iteración 99: f_min = [0.048 0.067], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0018 0.0527]
# Energías: inferior = 0.048, superior = 0.067
# v0 = -54.463834999999996, vls = -6.2686199999999825, Iteración = 99
# Iteración 100: f_min = [0.047 0.066], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0086 0.0518]
# Energías: inferior = 0.047, superior = 0.066
# v0 = -54.463404999999995, vls = -6.266029999999983, Iteración = 100
# Iteración 101: f_min = [0.046 0.064], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0016 0.0504]
# Energías: inferior = 0.046, superior = 0.064
# v0 = -54.463325, vls = -6.263509999999982, Iteración = 101
# Iteración 102: f_min = [0.045 0.063], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0018 0.0495]
# Energías: inferior = 0.045, superior = 0.063
# v0 = -54.463235, vls = -6.261034999999983, Iteración = 102
# Iteración 103: f_min = [0.045 0.062], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0057 0.049 ]
# Energías: inferior = 0.045, superior = 0.062
# v0 = -54.46295, vls = -6.258584999999982, Iteración = 103
# Iteración 104: f_min = [0.044 0.06 ], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0052 0.0416]
# Energías: inferior = 0.044, superior = 0.06
# v0 = -54.46269, vls = -6.256504999999982, Iteración = 104
# Iteración 105: f_min = [0.043 0.059], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.001  0.0408]
# Energías: inferior = 0.043, superior = 0.059
# v0 = -54.46264, vls = -6.254464999999982, Iteración = 105
# Iteración 106: f_min = [0.042 0.058], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0012 0.04  ]
# Energías: inferior = 0.042, superior = 0.058
# v0 = -54.46258, vls = -6.252464999999982, Iteración = 106
# Iteración 107: f_min = [0.042 0.057], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0048 0.0396]
# Energías: inferior = 0.042, superior = 0.057
# v0 = -54.462340000000005, vls = -6.2504849999999825, Iteración = 107
# Iteración 108: f_min = [0.041 0.056], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0008 0.0388]
# Energías: inferior = 0.041, superior = 0.056
# v0 = -54.462300000000006, vls = -6.248544999999982, Iteración = 108
# Iteración 109: f_min = [0.04  0.055], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.001 0.038]
# Energías: inferior = 0.04, superior = 0.055
# v0 = -54.462250000000004, vls = -6.246644999999982, Iteración = 109
# Iteración 110: f_min = [0.04  0.054], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0044 0.0376]
# Energías: inferior = 0.04, superior = 0.054
# v0 = -54.462030000000006, vls = -6.244764999999982, Iteración = 110
# Iteración 111: f_min = [0.039 0.053], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0006 0.0368]
# Energías: inferior = 0.039, superior = 0.053
# v0 = -54.462, vls = -6.242924999999982, Iteración = 111
# Iteración 112: f_min = [0.038 0.053], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0067 0.0417]
# Energías: inferior = 0.038, superior = 0.053
# v0 = -54.461665, vls = -6.240839999999982, Iteración = 112
# Iteración 113: f_min = [0.038 0.051], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.004  0.0356]
# Energías: inferior = 0.038, superior = 0.051
# v0 = -54.461465000000004, vls = -6.239059999999982, Iteración = 113
# Iteración 114: f_min = [0.037 0.05 ], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0004 0.0348]
# Energías: inferior = 0.037, superior = 0.05
# v0 = -54.461445000000005, vls = -6.237319999999982, Iteración = 114
# Iteración 115: f_min = [0.036 0.05 ], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0062 0.0394]
# Energías: inferior = 0.036, superior = 0.05
# v0 = -54.461135000000006, vls = -6.235349999999982, Iteración = 115
# Iteración 116: f_min = [0.036 0.049], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0091 0.0389]
# Energías: inferior = 0.036, superior = 0.049
# v0 = -54.46068, vls = -6.233404999999982, Iteración = 116
# Iteración 117: f_min = [0.035 0.047], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0002 0.0328]
# Energías: inferior = 0.035, superior = 0.047
# v0 = -54.46067, vls = -6.231764999999982, Iteración = 117
# Iteración 118: f_min = [0.035 0.047], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0084 0.0375]
# Energías: inferior = 0.035, superior = 0.047
# v0 = -54.46025, vls = -6.2298899999999815, Iteración = 118
# Iteración 119: f_min = [0.034 0.045], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [-0.0002  0.0316]
# Energías: inferior = 0.034, superior = 0.045
# v0 = -54.460260000000005, vls = -6.228309999999982, Iteración = 119
# Iteración 120: f_min = [0.034 0.045], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0032 0.0361]
# Energías: inferior = 0.034, superior = 0.045
# v0 = -54.460100000000004, vls = -6.226504999999982, Iteración = 120
# Iteración 121: f_min = [0.033 0.044], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [7.09010628e-16 3.52000000e-02]
# Energías: inferior = 0.033, superior = 0.044
# v0 = -54.460100000000004, vls = -6.224744999999982, Iteración = 121
# Iteración 122: f_min = [0.032 0.043], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0002 0.0343]
# Energías: inferior = 0.032, superior = 0.043
# v0 = -54.46009, vls = -6.223029999999982, Iteración = 122
# Iteración 123: f_min = [0.032 0.042], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0028 0.0296]
# Energías: inferior = 0.032, superior = 0.042
# v0 = -54.45995, vls = -6.221549999999982, Iteración = 123
# Iteración 124: f_min = [0.031 0.041], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [-0.0002  0.0288]
# Energías: inferior = 0.031, superior = 0.041
# v0 = -54.45996, vls = -6.220109999999982, Iteración = 124
# Iteración 125: f_min = [0.031 0.041], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0029 0.0329]
# Energías: inferior = 0.031, superior = 0.041
# v0 = -54.459815, vls = -6.218464999999982, Iteración = 125
# Iteración 126: f_min = [0.03 0.04], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [5.34100542e-16 3.20000000e-02]
# Energías: inferior = 0.03, superior = 0.04
# v0 = -54.459815, vls = -6.216864999999982, Iteración = 126
# Iteración 127: f_min = [0.029 0.039], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0002 0.0272]
# Energías: inferior = 0.029, superior = 0.039
# v0 = -54.459804999999996, vls = -6.215504999999982, Iteración = 127
# Iteración 128: f_min = [0.029 0.039], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0041 0.0311]
# Energías: inferior = 0.029, superior = 0.039
# v0 = -54.459599999999995, vls = -6.213949999999982, Iteración = 128
# Iteración 129: f_min = [0.028 0.038], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0004 0.0302]
# Energías: inferior = 0.028, superior = 0.038
# v0 = -54.459579999999995, vls = -6.212439999999982, Iteración = 129
# Iteración 130: f_min = [0.028 0.037], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0026 0.0297]
# Energías: inferior = 0.028, superior = 0.037
# v0 = -54.45945, vls = -6.2109549999999825, Iteración = 130
# Iteración 131: f_min = [0.027 0.036], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [3.55721008e-16 2.52000000e-02]
# Energías: inferior = 0.027, superior = 0.036
# v0 = -54.45945, vls = -6.209694999999982, Iteración = 131
# Iteración 132: f_min = [0.027 0.036], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0027 0.0288]
# Energías: inferior = 0.027, superior = 0.036
# v0 = -54.459315, vls = -6.2082549999999825, Iteración = 132
# Iteración 133: f_min = [0.026 0.035], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0002 0.0279]
# Energías: inferior = 0.026, superior = 0.035
# v0 = -54.45930499999999, vls = -6.206859999999982, Iteración = 133
# Iteración 134: f_min = [0.026 0.034], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0022 0.024 ]
# Energías: inferior = 0.026, superior = 0.034
# v0 = -54.459194999999994, vls = -6.205659999999982, Iteración = 134
# Iteración 135: f_min = [0.025 0.034], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0004 0.027 ]
# Energías: inferior = 0.025, superior = 0.034
# v0 = -54.459174999999995, vls = -6.204309999999982, Iteración = 135
# Iteración 136: f_min = [0.025 0.033], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [-0.0002  0.0265]
# Energías: inferior = 0.025, superior = 0.033
# v0 = -54.459185, vls = -6.202984999999981, Iteración = 136
# Iteración 137: f_min = [0.024 0.032], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [1.77341475e-16 2.24000000e-02]
# Energías: inferior = 0.024, superior = 0.032
# v0 = -54.459185, vls = -6.201864999999981, Iteración = 137
# Iteración 138: f_min = [0.024 0.032], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [1.77341475e-16 2.56000000e-02]
# Energías: inferior = 0.024, superior = 0.032
# v0 = -54.459185, vls = -6.200584999999981, Iteración = 138
# Iteración 139: f_min = [0.023 0.031], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0002 0.0216]
# Energías: inferior = 0.023, superior = 0.031
# v0 = -54.459174999999995, vls = -6.199504999999981, Iteración = 139
# Iteración 140: f_min = [0.023 0.031], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0002 0.0247]
# Energías: inferior = 0.023, superior = 0.031
# v0 = -54.45916499999999, vls = -6.19826999999998, Iteración = 140
# Iteración 141: f_min = [0.023 0.03 ], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0019 0.0212]
# Energías: inferior = 0.023, superior = 0.03
# v0 = -54.45906999999999, vls = -6.19720999999998, Iteración = 141
# Iteración 142: f_min = [0.022 0.03 ], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0004 0.0238]
# Energías: inferior = 0.022, superior = 0.03
# v0 = -54.45904999999999, vls = -6.196019999999979, Iteración = 142
# Iteración 143: f_min = [0.022 0.029], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.002  0.0204]
# Energías: inferior = 0.022, superior = 0.029
# v0 = -54.45894999999999, vls = -6.194999999999979, Iteración = 143
# Iteración 144: f_min = [0.021 0.029], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0035 0.0229]
# Energías: inferior = 0.021, superior = 0.029
# v0 = -54.45877499999999, vls = -6.193854999999979, Iteración = 144
# Iteración 145: f_min = [0.021 0.028], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [-1.03805853e-18  2.24000000e-02]
# Energías: inferior = 0.021, superior = 0.028
# v0 = -54.45877499999999, vls = -6.192734999999979, Iteración = 145
# Iteración 146: f_min = [0.021 0.027], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0015 0.0192]
# Energías: inferior = 0.021, superior = 0.027
# v0 = -54.458699999999986, vls = -6.1917749999999785, Iteración = 146
# Iteración 147: f_min = [0.02  0.027], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0002 0.0215]
# Energías: inferior = 0.02, superior = 0.027
# v0 = -54.45868999999998, vls = -6.190699999999978, Iteración = 147
# Iteración 148: f_min = [0.02  0.026], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0016 0.0184]
# Energías: inferior = 0.02, superior = 0.026
# v0 = -54.458609999999986, vls = -6.189779999999978, Iteración = 148
# Iteración 149: f_min = [0.02  0.026], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0016 0.021 ]
# Energías: inferior = 0.02, superior = 0.026
# v0 = -54.45852999999999, vls = -6.188729999999977, Iteración = 149
# Iteración 150: f_min = [0.019 0.025], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [-0.0002  0.0176]
# Energías: inferior = 0.019, superior = 0.025
# v0 = -54.45853999999999, vls = -6.187849999999977, Iteración = 150
# Iteración 151: f_min = [0.019 0.025], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0017 0.0201]
# Energías: inferior = 0.019, superior = 0.025
# v0 = -54.458454999999994, vls = -6.186844999999977, Iteración = 151
# Iteración 152: f_min = [0.018 0.025], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0031 0.0197]
# Energías: inferior = 0.018, superior = 0.025
# v0 = -54.458299999999994, vls = -6.185859999999977, Iteración = 152
# Iteración 153: f_min = [0.018 0.024], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [-1.77682868e-16  1.92000000e-02]
# Energías: inferior = 0.018, superior = 0.024
# v0 = -54.458299999999994, vls = -6.184899999999977, Iteración = 153
# Iteración 154: f_min = [0.018 0.024], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0042 0.0192]
# Energías: inferior = 0.018, superior = 0.024
# v0 = -54.45808999999999, vls = -6.183939999999977, Iteración = 154
# Iteración 155: f_min = [0.018 0.023], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0012 0.0187]
# Energías: inferior = 0.018, superior = 0.023
# v0 = -54.458029999999994, vls = -6.1830049999999765, Iteración = 155
# Iteración 156: f_min = [0.017 0.022], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [-0.0004  0.0156]
# Energías: inferior = 0.017, superior = 0.022
# v0 = -54.45804999999999, vls = -6.182224999999976, Iteración = 156
# Iteración 157: f_min = [0.017 0.022], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [-0.0004  0.0156]
# Energías: inferior = 0.017, superior = 0.022
# v0 = -54.45806999999999, vls = -6.181444999999975, Iteración = 157
# Iteración 158: f_min = [0.017 0.022], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0013 0.0178]
# Energías: inferior = 0.017, superior = 0.022
# v0 = -54.45800499999999, vls = -6.180554999999975, Iteración = 158
# Iteración 159: f_min = [0.016 0.021], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [-0.0002  0.0148]
# Energías: inferior = 0.016, superior = 0.021
# v0 = -54.458014999999996, vls = -6.179814999999975, Iteración = 159
# Iteración 160: f_min = [0.016 0.021], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [-0.0002  0.0169]
# Energías: inferior = 0.016, superior = 0.021
# v0 = -54.458025, vls = -6.178969999999975, Iteración = 160
# Iteración 161: f_min = [0.016 0.021], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0035 0.0169]
# Energías: inferior = 0.016, superior = 0.021
# v0 = -54.45785, vls = -6.178124999999975, Iteración = 161
# Iteración 162: f_min = [0.015 0.02 ], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [-3.02059766e-15  1.40000000e-02]
# Energías: inferior = 0.015, superior = 0.02
# v0 = -54.45785, vls = -6.177424999999975, Iteración = 162
# Iteración 163: f_min = [0.015 0.02 ], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [-3.02059766e-15  1.60000000e-02]
# Energías: inferior = 0.015, superior = 0.02
# v0 = -54.45785, vls = -6.176624999999975, Iteración = 163
# Iteración 164: f_min = [0.015 0.019], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0009 0.0136]
# Energías: inferior = 0.015, superior = 0.019
# v0 = -54.457805, vls = -6.175944999999975, Iteración = 164
# Iteración 165: f_min = [0.015 0.019], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0009 0.0155]
# Energías: inferior = 0.015, superior = 0.019
# v0 = -54.45776, vls = -6.175169999999975, Iteración = 165
# Iteración 166: f_min = [0.014 0.019], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0002 0.0151]
# Energías: inferior = 0.014, superior = 0.019
# v0 = -54.45775, vls = -6.174414999999975, Iteración = 166
# Iteración 167: f_min = [0.014 0.018], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [-0.0004  0.0128]
# Energías: inferior = 0.014, superior = 0.018
# v0 = -54.45777, vls = -6.173774999999974, Iteración = 167
# Iteración 168: f_min = [0.014 0.018], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.001  0.0146]
# Energías: inferior = 0.014, superior = 0.018
# v0 = -54.457719999999995, vls = -6.173044999999974, Iteración = 168
# Iteración 169: f_min = [0.014 0.018], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.001  0.0146]
# Energías: inferior = 0.014, superior = 0.018
# v0 = -54.45766999999999, vls = -6.1723149999999745, Iteración = 169
# Iteración 170: f_min = [0.013 0.017], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [-0.0002  0.012 ]
# Energías: inferior = 0.013, superior = 0.017
# v0 = -54.457679999999996, vls = -6.171714999999974, Iteración = 170
# Iteración 171: f_min = [0.013 0.017], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [-0.0002  0.0137]
# Energías: inferior = 0.013, superior = 0.017
# v0 = -54.45769, vls = -6.171029999999974, Iteración = 171
# Iteración 172: f_min = [0.013 0.017], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0011 0.0137]
# Energías: inferior = 0.013, superior = 0.017
# v0 = -54.457634999999996, vls = -6.170344999999974, Iteración = 172
# Iteración 173: f_min = [0.012 0.016], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [-2.66468236e-15  1.12000000e-02]
# Energías: inferior = 0.012, superior = 0.016
# v0 = -54.457634999999996, vls = -6.169784999999974, Iteración = 173
# Iteración 174: f_min = [0.012 0.016], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [-2.66468236e-15  1.12000000e-02]
# Energías: inferior = 0.012, superior = 0.016
# v0 = -54.457634999999996, vls = -6.169224999999974, Iteración = 174
# Iteración 175: f_min = [0.012 0.016], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [-2.66468236e-15  1.28000000e-02]
# Energías: inferior = 0.012, superior = 0.016
# v0 = -54.457634999999996, vls = -6.1685849999999744, Iteración = 175
# Iteración 176: f_min = [0.012 0.016], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0028 0.0128]
# Energías: inferior = 0.012, superior = 0.016
# v0 = -54.457494999999994, vls = -6.167944999999975, Iteración = 176
# Iteración 177: f_min = [0.012 0.015], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0006 0.0108]
# Energías: inferior = 0.012, superior = 0.015
# v0 = -54.45746499999999, vls = -6.167404999999975, Iteración = 177
# Iteración 178: f_min = [0.011 0.015], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0002 0.0119]
# Energías: inferior = 0.011, superior = 0.015
# v0 = -54.45745499999999, vls = -6.166809999999974, Iteración = 178
# Iteración 179: f_min = [0.011 0.015], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0002 0.0119]
# Energías: inferior = 0.011, superior = 0.015
# v0 = -54.457444999999986, vls = -6.166214999999974, Iteración = 179
# Iteración 180: f_min = [0.011 0.014], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [-0.0004  0.01  ]
# Energías: inferior = 0.011, superior = 0.014
# v0 = -54.457464999999985, vls = -6.165714999999974, Iteración = 180
# Iteración 181: f_min = [0.011 0.014], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0007 0.01  ]
# Energías: inferior = 0.011, superior = 0.014
# v0 = -54.45742999999999, vls = -6.165214999999974, Iteración = 181
# Iteración 182: f_min = [0.011 0.014], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0007 0.0114]
# Energías: inferior = 0.011, superior = 0.014
# v0 = -54.45739499999999, vls = -6.164644999999974, Iteración = 182
# Iteración 183: f_min = [0.01  0.014], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0018 0.011 ]
# Energías: inferior = 0.01, superior = 0.014
# v0 = -54.45730499999999, vls = -6.164094999999974, Iteración = 183
# Iteración 184: f_min = [0.01  0.013], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [-0.0002  0.0092]
# Energías: inferior = 0.01, superior = 0.013
# v0 = -54.457314999999994, vls = -6.1636349999999736, Iteración = 184
# Iteración 185: f_min = [0.01  0.013], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [-0.0002  0.0092]
# Energías: inferior = 0.01, superior = 0.013
# v0 = -54.457325, vls = -6.163174999999973, Iteración = 185
# Iteración 186: f_min = [0.01  0.013], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0008 0.0105]
# Energías: inferior = 0.01, superior = 0.013
# v0 = -54.457285, vls = -6.162649999999973, Iteración = 186
# Iteración 187: f_min = [0.01  0.013], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0008 0.0105]
# Energías: inferior = 0.01, superior = 0.013
# v0 = -54.457245, vls = -6.162124999999972, Iteración = 187
# Iteración 188: f_min = [0.009 0.012], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [-2.30963443e-15  8.40000000e-03]
# Energías: inferior = 0.009, superior = 0.012
# v0 = -54.457245, vls = -6.161704999999972, Iteración = 188
# Iteración 189: f_min = [0.009 0.012], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [-2.30963443e-15  8.40000000e-03]
# Energías: inferior = 0.009, superior = 0.012
# v0 = -54.457245, vls = -6.161284999999972, Iteración = 189
# Iteración 190: f_min = [0.009 0.012], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [-2.30963443e-15  9.60000000e-03]
# Energías: inferior = 0.009, superior = 0.012
# v0 = -54.457245, vls = -6.160804999999971, Iteración = 190
# Iteración 191: f_min = [0.009 0.012], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [-2.30963443e-15  9.60000000e-03]
# Energías: inferior = 0.009, superior = 0.012
# v0 = -54.457245, vls = -6.160324999999971, Iteración = 191
# Iteración 192: f_min = [0.009 0.012], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0021 0.0096]
# Energías: inferior = 0.009, superior = 0.012
# v0 = -54.45714, vls = -6.1598449999999705, Iteración = 192
# Iteración 193: f_min = [0.009 0.011], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0003 0.008 ]
# Energías: inferior = 0.009, superior = 0.011
# v0 = -54.457125000000005, vls = -6.1594449999999705, Iteración = 193
# Iteración 194: f_min = [0.009 0.011], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0003 0.0091]
# Energías: inferior = 0.009, superior = 0.011
# v0 = -54.45711000000001, vls = -6.15898999999997, Iteración = 194
# Iteración 195: f_min = [0.008 0.011], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0002 0.0087]
# Energías: inferior = 0.008, superior = 0.011
# v0 = -54.457100000000004, vls = -6.15855499999997, Iteración = 195
# Iteración 196: f_min = [0.008 0.011], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0002 0.0087]
# Energías: inferior = 0.008, superior = 0.011
# v0 = -54.45709, vls = -6.158119999999969, Iteración = 196
# Iteración 197: f_min = [0.008 0.01 ], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [-0.0004  0.0072]
# Energías: inferior = 0.008, superior = 0.01
# v0 = -54.45711, vls = -6.1577599999999695, Iteración = 197
# Iteración 198: f_min = [0.008 0.01 ], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0004 0.0072]
# Energías: inferior = 0.008, superior = 0.01
# v0 = -54.45709, vls = -6.15739999999997, Iteración = 198
# Iteración 199: f_min = [0.008 0.01 ], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0004 0.0072]
# Energías: inferior = 0.008, superior = 0.01
# v0 = -54.45707, vls = -6.15703999999997, Iteración = 199
# Iteración 200: f_min = [0.008 0.01 ], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0004 0.0082]
# Energías: inferior = 0.008, superior = 0.01
# v0 = -54.45705, vls = -6.15662999999997, Iteración = 200
# Iteración 201: f_min = [0.007 0.01 ], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0004 0.0078]
# Energías: inferior = 0.007, superior = 0.01
# v0 = -54.45703, vls = -6.156239999999969, Iteración = 201
# Iteración 202: f_min = [0.007 0.01 ], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0014 0.0078]
# Energías: inferior = 0.007, superior = 0.01
# v0 = -54.45696, vls = -6.155849999999969, Iteración = 202
# Iteración 203: f_min = [0.007 0.009], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [-0.0002  0.0064]
# Energías: inferior = 0.007, superior = 0.009
# v0 = -54.456970000000005, vls = -6.155529999999969, Iteración = 203
# Iteración 204: f_min = [0.007 0.009], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [-0.0002  0.0064]
# Energías: inferior = 0.007, superior = 0.009
# v0 = -54.45698000000001, vls = -6.155209999999968, Iteración = 204
# Iteración 205: f_min = [0.007 0.009], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [-0.0002  0.0073]
# Energías: inferior = 0.007, superior = 0.009
# v0 = -54.45699000000001, vls = -6.154844999999968, Iteración = 205
# Iteración 206: f_min = [0.007 0.009], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0005 0.0073]
# Energías: inferior = 0.007, superior = 0.009
# v0 = -54.45696500000001, vls = -6.1544799999999675, Iteración = 206
# Iteración 207: f_min = [0.007 0.009], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0005 0.0073]
# Energías: inferior = 0.007, superior = 0.009
# v0 = -54.45694000000001, vls = -6.154114999999967, Iteración = 207
# Iteración 208: f_min = [0.007 0.009], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0014 0.0073]
# Energías: inferior = 0.007, superior = 0.009
# v0 = -54.45687000000001, vls = -6.153749999999967, Iteración = 208
# Iteración 209: f_min = [0.006 0.008], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [-1.95371913e-15  5.60000000e-03]
# Energías: inferior = 0.006, superior = 0.008
# v0 = -54.45687000000001, vls = -6.153469999999967, Iteración = 209
# Iteración 210: f_min = [0.006 0.008], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [-1.95371913e-15  5.60000000e-03]
# Energías: inferior = 0.006, superior = 0.008
# v0 = -54.45687000000001, vls = -6.153189999999967, Iteración = 210
# Iteración 211: f_min = [0.006 0.008], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [-1.95371913e-15  6.40000000e-03]
# Energías: inferior = 0.006, superior = 0.008
# v0 = -54.45687000000001, vls = -6.152869999999966, Iteración = 211
# Iteración 212: f_min = [0.006 0.008], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [-1.95371913e-15  6.40000000e-03]
# Energías: inferior = 0.006, superior = 0.008
# v0 = -54.45687000000001, vls = -6.152549999999966, Iteración = 212
# Iteración 213: f_min = [0.006 0.008], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [-1.95371913e-15  6.40000000e-03]
# Energías: inferior = 0.006, superior = 0.008
# v0 = -54.45687000000001, vls = -6.152229999999966, Iteración = 213
# Iteración 214: f_min = [0.006 0.008], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0014 0.0064]
# Energías: inferior = 0.006, superior = 0.008
# v0 = -54.45680000000001, vls = -6.151909999999965, Iteración = 214
# Iteración 215: f_min = [0.006 0.007], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [-7.7724216e-16  5.2000000e-03]
# Energías: inferior = 0.006, superior = 0.007
# v0 = -54.45680000000001, vls = -6.151649999999965, Iteración = 215
# Iteración 216: f_min = [0.006 0.007], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [-7.7724216e-16  5.2000000e-03]
# Energías: inferior = 0.006, superior = 0.007
# v0 = -54.45680000000001, vls = -6.1513899999999655, Iteración = 216
# Iteración 217: f_min = [0.006 0.007], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [-7.7724216e-16  5.2000000e-03]
# Energías: inferior = 0.006, superior = 0.007
# v0 = -54.45680000000001, vls = -6.151129999999966, Iteración = 217
# Iteración 218: f_min = [0.005 0.007], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0002 0.0055]
# Energías: inferior = 0.005, superior = 0.007
# v0 = -54.456790000000005, vls = -6.150854999999965, Iteración = 218
# Iteración 219: f_min = [0.005 0.007], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0002 0.0055]
# Energías: inferior = 0.005, superior = 0.007
# v0 = -54.45678, vls = -6.150579999999965, Iteración = 219
# Iteración 220: f_min = [0.005 0.007], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0002 0.0055]
# Energías: inferior = 0.005, superior = 0.007
# v0 = -54.45677, vls = -6.150304999999965, Iteración = 220
# Iteración 221: f_min = [0.005 0.007], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0002 0.0055]
# Energías: inferior = 0.005, superior = 0.007
# ...
# [[ 0.8 -0.4]
#  [-0.4 -0.4]]
# Gradiente = [-0.0012  0.0036]
# Energías: inferior = 0.004, superior = 0.005
# v0 = -54.456864999999986, vls = -6.147364999999961, Iteración = 233
# Iteración 234: f_min = [0.004 0.005], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.4 -0.4]]
# Gradiente = [-0.0008  0.0036]
# Energías: inferior = 0.004, superior = 0.005
# v0 = -54.456904999999985, vls = -6.14718499999996, Iteración = 234
# Iteración 235: f_min = [0.004 0.005], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.4 -0.4]]
# Gradiente = [-0.0008  0.0036]
# Energías: inferior = 0.004, superior = 0.005
# v0 = -54.45694499999998, vls = -6.14700499999996, Iteración = 235
# Iteración 236: f_min = [0.004 0.005], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.4 -0.4]]
# Gradiente = [-0.0008  0.0036]
# Energías: inferior = 0.004, superior = 0.005
# v0 = -54.45698499999998, vls = -6.14682499999996, Iteración = 236
# Iteración 237: f_min = [0.004 0.005], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.4 -0.4]]
# Gradiente = [-0.0008  0.0036]
# Energías: inferior = 0.004, superior = 0.005
# v0 = -54.45702499999998, vls = -6.1466449999999595, Iteración = 237
# Iteración 238: f_min = [0.003 0.005], Jacobiano =
# [[ 0.8 -0.2]
#  [-0.4 -0.4]]
# Gradiente = [-0.0004  0.0026]
# Energías: inferior = 0.003, superior = 0.005
# v0 = -54.45704499999998, vls = -6.146514999999959, Iteración = 238
# Iteración 239: f_min = [0.003 0.005], Jacobiano =
# [[ 0.8 -0.2]
#  [-0.4 -0.5]]
# Gradiente = [-0.0004  0.0031]
# Energías: inferior = 0.003, superior = 0.005
# v0 = -54.45706499999998, vls = -6.146359999999959, Iteración = 239
# Iteración 240: f_min = [0.003 0.005], Jacobiano =
# [[ 0.8 -0.2]
#  [-0.4 -0.5]]
# Gradiente = [-0.0004  0.0031]
# Energías: inferior = 0.003, superior = 0.005
# v0 = -54.45708499999998, vls = -6.146204999999958, Iteración = 240
# Iteración 241: f_min = [0.003 0.005], Jacobiano =
# [[ 0.8 -0.2]
#  [-0.4 -0.5]]
# Gradiente = [-0.0004  0.0031]
# Energías: inferior = 0.003, superior = 0.005
# v0 = -54.45710499999998, vls = -6.146049999999958, Iteración = 241
# Iteración 242: f_min = [0.003 0.005], Jacobiano =
# [[ 0.8 -0.2]
#  [-0.4 -0.5]]
# Gradiente = [-0.0004  0.0031]
# Energías: inferior = 0.003, superior = 0.005
# v0 = -54.45712499999998, vls = -6.145894999999958, Iteración = 242
# Iteración 243: f_min = [0.003 0.005], Jacobiano =
# [[ 0.8 -0.2]
#  [-0.4 -0.5]]
# Gradiente = [-0.0004  0.0031]
# Energías: inferior = 0.003, superior = 0.005
# v0 = -54.457144999999976, vls = -6.145739999999957, Iteración = 243
# Iteración 244: f_min = [0.003 0.005], Jacobiano =
# [[ 0.8 -0.2]
#  [-0.4 -0.5]]
# Gradiente = [-0.0004  0.0031]
# Energías: inferior = 0.003, superior = 0.005
# v0 = -54.457164999999975, vls = -6.145584999999957, Iteración = 244
# Iteración 245: f_min = [0.003 0.005], Jacobiano =
# [[ 0.8 -0.2]
#  [-0.4 -0.5]]
# Gradiente = [-0.0004  0.0031]
# Energías: inferior = 0.003, superior = 0.005
# v0 = -54.457184999999974, vls = -6.145429999999957, Iteración = 245
# Iteración 246: f_min = [0.003 0.005], Jacobiano =
# [[ 0.7 -0.2]
#  [-0.4 -0.5]]
# Gradiente = [-1.0e-04  3.1e-03]
# Energías: inferior = 0.003, superior = 0.005
# v0 = -54.457189999999976, vls = -6.145274999999956, Iteración = 246
# Iteración 247: f_min = [0.003 0.005], Jacobiano =
# [[ 0.7 -0.2]
#  [-0.3 -0.5]]
# Gradiente = [-0.0006  0.0031]
# Energías: inferior = 0.003, superior = 0.005
# v0 = -54.45721999999998, vls = -6.145119999999956, Iteración = 247
# Iteración 248: f_min = [0.003 0.005], Jacobiano =
# [[ 0.7 -0.2]
#  [-0.3 -0.5]]
# Gradiente = [-0.0006  0.0031]
# Energías: inferior = 0.003, superior = 0.005
# v0 = -54.45724999999998, vls = -6.144964999999956, Iteración = 248
# Iteración 249: f_min = [0.003 0.004], Jacobiano =
# [[ 0.7 -0.2]
#  [-0.2 -0.4]]
# Gradiente = [-0.0013  0.0022]
# Energías: inferior = 0.003, superior = 0.004
# v0 = -54.45731499999998, vls = -6.144854999999955, Iteración = 249
# Iteración 250: f_min = [0.003 0.004], Jacobiano =
# [[ 0.7 -0.2]
#  [-0.2 -0.4]]
# Gradiente = [-0.0013  0.0022]
# Energías: inferior = 0.003, superior = 0.004
# v0 = -54.45737999999998, vls = -6.144744999999955, Iteración = 250
# Iteración 251: f_min = [0.002 0.004], Jacobiano =
# [[ 8.0000000e-01 -8.8817842e-13]
#  [-2.0000000e-01 -4.0000000e-01]]
# Gradiente = [-0.0008  0.0016]
# Energías: inferior = 0.002, superior = 0.004
# v0 = -54.45741999999998, vls = -6.1446649999999545, Iteración = 251
# Iteración 252: f_min = [0.002 0.004], Jacobiano =
# [[ 8.0000000e-01 -8.8817842e-13]
#  [-2.0000000e-01 -4.0000000e-01]]
# Gradiente = [-0.0008  0.0016]
# Energías: inferior = 0.002, superior = 0.004
# v0 = -54.457459999999976, vls = -6.144584999999954, Iteración = 252
# Iteración 253: f_min = [0.002 0.004], Jacobiano =
# [[ 8.0000000e-01 -8.8817842e-13]
#  [-2.0000000e-01 -4.0000000e-01]]
# Gradiente = [-0.0008  0.0016]
# Energías: inferior = 0.002, superior = 0.004
# v0 = -54.457499999999975, vls = -6.1445049999999535, Iteración = 253
# Iteración 254: f_min = [0.002 0.004], Jacobiano =
# [[ 8.0000000e-01 -8.8817842e-13]
#  [-2.0000000e-01 -4.0000000e-01]]
# Gradiente = [-0.0008  0.0016]
# Energías: inferior = 0.002, superior = 0.004
# v0 = -54.45753999999997, vls = -6.144424999999953, Iteración = 254
# Iteración 255: f_min = [0.002 0.004], Jacobiano =
# [[ 8.0000000e-01 -8.8817842e-13]
#  [-2.0000000e-01 -4.0000000e-01]]
# Gradiente = [-0.0008  0.0016]
# Energías: inferior = 0.002, superior = 0.004
# v0 = -54.45757999999997, vls = -6.144344999999952, Iteración = 255
# Iteración 256: f_min = [0.002 0.004], Jacobiano =
# [[ 8.0000000e-01 -8.8817842e-13]
#  [-2.0000000e-01 -4.0000000e-01]]
# Gradiente = [-0.0008  0.0016]
# Energías: inferior = 0.002, superior = 0.004
# v0 = -54.45761999999997, vls = -6.144264999999952, Iteración = 256
# Iteración 257: f_min = [0.002 0.004], Jacobiano =
# [[ 8.0000000e-01 -8.8817842e-13]
#  [-2.0000000e-01 -4.0000000e-01]]
# Gradiente = [-0.0008  0.0016]
# Energías: inferior = 0.002, superior = 0.004
# v0 = -54.45765999999997, vls = -6.144184999999951, Iteración = 257
# Iteración 258: f_min = [0.002 0.004], Jacobiano =
# [[ 8.0000000e-01 -8.8817842e-13]
#  [-2.0000000e-01 -4.0000000e-01]]
# Gradiente = [-0.0008  0.0016]
# Energías: inferior = 0.002, superior = 0.004
# v0 = -54.45769999999997, vls = -6.144104999999951, Iteración = 258
# Iteración 259: f_min = [0.002 0.004], Jacobiano =
# [[ 8.0000000e-01 -8.8817842e-13]
#  [-2.0000000e-01 -4.0000000e-01]]
# Gradiente = [-0.0008  0.0016]
# Energías: inferior = 0.002, superior = 0.004
# v0 = -54.457739999999966, vls = -6.14402499999995, Iteración = 259
# Iteración 260: f_min = [0.002 0.004], Jacobiano =
# [[ 7.0000000e-01 -8.8817842e-13]
#  [-2.0000000e-01 -4.0000000e-01]]
# Gradiente = [-0.0006  0.0016]
# Energías: inferior = 0.002, superior = 0.004
# v0 = -54.45776999999997, vls = -6.14394499999995, Iteración = 260
# Iteración 261: f_min = [0.002 0.004], Jacobiano =
# [[ 7.0000000e-01 -8.8817842e-13]
#  [-2.0000000e-01 -4.0000000e-01]]
# Gradiente = [-0.0006  0.0016]
# Energías: inferior = 0.002, superior = 0.004
# v0 = -54.45779999999997, vls = -6.143864999999949, Iteración = 261
# Iteración 262: f_min = [0.002 0.004], Jacobiano =
# [[ 7.0000000e-01 -8.8817842e-13]
#  [-2.0000000e-01 -4.0000000e-01]]
# Gradiente = [-0.0006  0.0016]
# Energías: inferior = 0.002, superior = 0.004
# v0 = -54.45782999999997, vls = -6.143784999999949, Iteración = 262
# Iteración 263: f_min = [0.002 0.004], Jacobiano =
# [[ 7.0000000e-01 -8.8817842e-13]
#  [-2.0000000e-01 -4.0000000e-01]]
# Gradiente = [-0.0006  0.0016]
# Energías: inferior = 0.002, superior = 0.004
# v0 = -54.457859999999975, vls = -6.143704999999948, Iteración = 263
# Iteración 264: f_min = [0.002 0.004], Jacobiano =
# [[ 7.0000000e-01 -8.8817842e-13]
#  [-2.0000000e-01 -4.0000000e-01]]
# Gradiente = [-0.0006  0.0016]
# Energías: inferior = 0.002, superior = 0.004
# v0 = -54.45788999999998, vls = -6.143624999999948, Iteración = 264
# Iteración 265: f_min = [0.002 0.004], Jacobiano =
# [[ 7.0000000e-01 -8.8817842e-13]
#  [-2.0000000e-01 -4.0000000e-01]]
# Gradiente = [-0.0006  0.0016]
# Energías: inferior = 0.002, superior = 0.004
# v0 = -54.45791999999998, vls = -6.143544999999947, Iteración = 265
# Iteración 266: f_min = [0.002 0.004], Jacobiano =
# [[ 7.0000000e-01 -8.8817842e-13]
#  [-2.0000000e-01 -4.0000000e-01]]
# Gradiente = [-0.0006  0.0016]
# Energías: inferior = 0.002, superior = 0.004
# v0 = -54.45794999999998, vls = -6.143464999999947, Iteración = 266
# Iteración 267: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.4]]
# Gradiente = [-1.06579745e-15  1.40000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.45794999999998, vls = -6.143394999999947, Iteración = 267
# Iteración 268: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.4]]
# Gradiente = [-1.06579745e-15  1.40000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.45794999999998, vls = -6.143324999999947, Iteración = 268
# Iteración 269: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.4]]
# Gradiente = [-1.06579745e-15  1.40000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.45794999999998, vls = -6.143254999999947, Iteración = 269
# Iteración 270: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.4]]
# Gradiente = [-1.06579745e-15  1.40000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.45794999999998, vls = -6.143184999999947, Iteración = 270
# Iteración 271: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.3]]
# Gradiente = [-1.06579745e-15  1.00000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.45794999999998, vls = -6.143134999999947, Iteración = 271
# Iteración 272: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.3]]
# Gradiente = [-1.06579745e-15  1.00000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.45794999999998, vls = -6.143084999999947, Iteración = 272
# Iteración 273: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.3]]
# Gradiente = [-1.06579745e-15  1.00000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.45794999999998, vls = -6.143034999999947, Iteración = 273
# Iteración 274: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.3]]
# Gradiente = [-1.06579745e-15  1.00000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.45794999999998, vls = -6.142984999999947, Iteración = 274
# Iteración 275: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.3]]
# Gradiente = [-1.06579745e-15  1.00000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.45794999999998, vls = -6.142934999999947, Iteración = 275
# Iteración 276: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.3]]
# Gradiente = [-1.06579745e-15  1.00000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.45794999999998, vls = -6.142884999999947, Iteración = 276
# Iteración 277: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.3]]
# Gradiente = [-1.06579745e-15  1.00000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.45794999999998, vls = -6.142834999999947, Iteración = 277
# Iteración 278: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.3]]
# Gradiente = [-1.06579745e-15  1.00000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.45794999999998, vls = -6.1427849999999475, Iteración = 278
# Iteración 279: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.3]]
# Gradiente = [-1.06579745e-15  1.00000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.45794999999998, vls = -6.142734999999948, Iteración = 279
# Iteración 280: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.3]]
# Gradiente = [-1.06579745e-15  1.00000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.45794999999998, vls = -6.142684999999948, Iteración = 280
# Iteración 281: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.3]]
# Gradiente = [-1.06579745e-15  1.00000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.45794999999998, vls = -6.142634999999948, Iteración = 281
# Iteración 282: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.3]]
# Gradiente = [-1.06579745e-15  1.00000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.45794999999998, vls = -6.142584999999948, Iteración = 282
# Iteración 283: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.3]]
# Gradiente = [-1.06579745e-15  1.00000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.45794999999998, vls = -6.142534999999948, Iteración = 283
# Iteración 284: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.3]]
# Gradiente = [-1.06579745e-15  1.00000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.45794999999998, vls = -6.142484999999948, Iteración = 284
# Iteración 285: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.3]]
# Gradiente = [-1.06579745e-15  1.00000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.45794999999998, vls = -6.142434999999948, Iteración = 285
# Iteración 286: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.3]]
# Gradiente = [-1.06579745e-15  1.00000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.45794999999998, vls = -6.1423849999999485, Iteración = 286
# Iteración 287: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.3]]
# Gradiente = [-1.06579745e-15  1.00000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.45794999999998, vls = -6.142334999999949, Iteración = 287
# Iteración 288: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.3]]
# Gradiente = [-1.06579745e-15  1.00000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.45794999999998, vls = -6.142284999999949, Iteración = 288
# Iteración 289: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.3]]
# Gradiente = [-1.06579745e-15  1.00000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.45794999999998, vls = -6.142234999999949, Iteración = 289
# Iteración 290: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.3]]
# Gradiente = [-1.06579745e-15  1.00000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.45794999999998, vls = -6.142184999999949, Iteración = 290
# Iteración 291: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.1 -0.3]]
# Gradiente = [-0.0004  0.001 ]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.45796999999998, vls = -6.142134999999949, Iteración = 291
# Iteración 292: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.1 -0.3]]
# Gradiente = [-0.0004  0.001 ]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.45798999999998, vls = -6.142084999999949, Iteración = 292
# Iteración 293: f_min = [0.001 0.004], Jacobiano =
# [[ 0.7  0.2]
#  [-0.1 -0.3]]
# Gradiente = [-0.0003  0.001 ]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.45800499999998, vls = -6.142034999999949, Iteración = 293
# Iteración 294: f_min = [0.001 0.004], Jacobiano =
# [[ 0.7  0.2]
#  [-0.1 -0.3]]
# Gradiente = [-0.0003  0.001 ]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.458019999999976, vls = -6.141984999999949, Iteración = 294
# Iteración 295: f_min = [0.001 0.004], Jacobiano =
# [[ 0.7  0.2]
#  [-0.1 -0.3]]
# Gradiente = [-0.0003  0.001 ]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.458034999999974, vls = -6.1419349999999495, Iteración = 295
# Iteración 296: f_min = [0.001 0.004], Jacobiano =
# [[ 0.7  0.2]
#  [-0.1 -0.3]]
# Gradiente = [-0.0003  0.001 ]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.45804999999997, vls = -6.14188499999995, Iteración = 296
# Iteración 297: f_min = [0.001 0.004], Jacobiano =
# [[ 0.7  0.2]
#  [-0.1 -0.3]]
# Gradiente = [-0.0003  0.001 ]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.45806499999997, vls = -6.14183499999995, Iteración = 297
# Iteración 298: f_min = [0.001 0.004], Jacobiano =
# [[ 0.7  0.2]
#  [-0.1 -0.3]]
# Gradiente = [-0.0003  0.001 ]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.45807999999997, vls = -6.14178499999995, Iteración = 298
# Iteración 299: f_min = [0.001 0.004], Jacobiano =
# [[ 0.7  0.2]
#  [-0.1 -0.3]]
# Gradiente = [-0.0003  0.001 ]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.458094999999965, vls = -6.14173499999995, Iteración = 299
# Iteración 300: f_min = [0.001 0.004], Jacobiano =
# [[ 0.7  0.2]
#  [-0.1 -0.3]]
# Gradiente = [-0.0003  0.001 ]
# Energías: inferior = 0.001, superior = 0.004
# Converged after 300 iterations.
# Minimum found at:
#  V_0 = -54.45810999999996, V_LS = -6.14168499999995

# %% [markdown]
# ## Neutrones

# %%
modificar_isotopo(camino,Ca40,tipo=0)

jacobian_gradient_descent(nucleo=Ca40,tipo=0,eta1=5e-2,eta2=5e-2,tolerancia=3e-3,max_iter=10000,v0=-55.0,vls=-7.0)
# Out:
# Iteración 0: f_min = [0.683 0.74 ], Jacobiano =
# [[-0.8  0.3]
#  [-0.6 -0.4]]
# Gradiente = [0.9904 0.0911]
# Energías: inferior = 0.683, superior = 0.74
# v0 = -54.95048, vls = -6.995445000000002, Iteración = 0
# Iteración 1: f_min = [0.646 0.706], Jacobiano =
# [[-0.8  0.3]
#  [-0.6 -0.5]]
# Gradiente = [0.9404 0.1592]
# Energías: inferior = 0.646, superior = 0.706
# v0 = -54.90346, vls = -6.9874849999999995, Iteración = 1
# Iteración 2: f_min = [0.612 0.672], Jacobiano =
# [[-0.8  0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.96   0.0912]
# Energías: inferior = 0.612, superior = 0.672
# v0 = -54.855459999999994, vls = -6.98292499999999, Iteración = 2
# Iteración 3: f_min = [0.576 0.639], Jacobiano =
# [[-0.8  0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.9081 0.0891]
# Energías: inferior = 0.576, superior = 0.639
# v0 = -54.81005499999999, vls = -6.978469999999992, Iteración = 3
# Iteración 4: f_min = [0.542 0.607], Jacobiano =
# [[-0.7  0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.7436 0.026 ]
# Energías: inferior = 0.542, superior = 0.607
# v0 = -54.772874999999985, vls = -6.977169999999981, Iteración = 4
# Iteración 5: f_min = [0.514 0.583], Jacobiano =
# [[-0.8  0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.8193 0.0859]
# Energías: inferior = 0.514, superior = 0.583
# v0 = -54.731909999999985, vls = -6.972874999999988, Iteración = 5
# Iteración 6: f_min = [0.484 0.554], Jacobiano =
# [[-0.8  0.3]
#  [-0.6 -0.5]]
# Gradiente = [0.7196 0.1318]
# Energías: inferior = 0.484, superior = 0.554
# v0 = -54.695929999999976, vls = -6.966284999999991, Iteración = 6
# Iteración 7: f_min = [0.458 0.528], Jacobiano =
# [[-0.8  0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.736  0.0808]
# Energías: inferior = 0.458, superior = 0.528
# v0 = -54.65912999999997, vls = -6.962244999999984, Iteración = 7
# Iteración 8: f_min = [0.431 0.502], Jacobiano =
# [[-0.8  0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.646  0.0786]
# Energías: inferior = 0.431, superior = 0.502
# v0 = -54.62682999999997, vls = -6.958314999999986, Iteración = 8
# Iteración 9: f_min = [0.407 0.479], Jacobiano =
# [[-0.8  0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.613  0.0288]
# Energías: inferior = 0.407, superior = 0.479
# v0 = -54.59617999999997, vls = -6.956874999999985, Iteración = 9
# Iteración 10: f_min = [0.384 0.459], Jacobiano =
# [[-0.8  0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.6285 0.0759]
# Energías: inferior = 0.384, superior = 0.459
# v0 = -54.56475499999997, vls = -6.95307999999999, Iteración = 10
# Iteración 11: f_min = [0.361 0.437], Jacobiano =
# [[-0.8  0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.5947 0.0741]
# Energías: inferior = 0.361, superior = 0.437
# v0 = -54.53501999999997, vls = -6.949374999999991, Iteración = 11
# Iteración 12: f_min = [0.339 0.416], Jacobiano =
# [[-0.8  0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.5624 0.0724]
# Energías: inferior = 0.339, superior = 0.416
# v0 = -54.506899999999966, vls = -6.945754999999989, Iteración = 12
# Iteración 13: f_min = [0.318 0.396], Jacobiano =
# [[-0.7  0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.4602 0.0708]
# Energías: inferior = 0.318, superior = 0.396
# v0 = -54.48388999999997, vls = -6.942214999999987, Iteración = 13
# Iteración 14: f_min = [0.302 0.38 ], Jacobiano =
# [[-0.8  0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.5076 0.0692]
# Energías: inferior = 0.302, superior = 0.38
# v0 = -54.45850999999997, vls = -6.9387549999999845, Iteración = 14
# Iteración 15: f_min = [0.283 0.362], Jacobiano =
# [[-0.7  0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.4515 0.0678]
# Energías: inferior = 0.283, superior = 0.362
# v0 = -54.43593499999997, vls = -6.935364999999986, Iteración = 15
# Iteración 16: f_min = [0.267 0.345], Jacobiano =
# [[-0.8  0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.4206 0.0312]
# Energías: inferior = 0.267, superior = 0.345
# v0 = -54.41490499999997, vls = -6.933804999999986, Iteración = 16
# Iteración 17: f_min = [0.251 0.331], Jacobiano =
# [[-0.7  0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.3743 0.0651]
# Energías: inferior = 0.251, superior = 0.331
# v0 = -54.39618999999997, vls = -6.930549999999984, Iteración = 17
# Iteración 18: f_min = [0.238 0.318], Jacobiano =
# [[-0.8  0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.413  0.0638]
# Energías: inferior = 0.238, superior = 0.318
# v0 = -54.375539999999965, vls = -6.927359999999985, Iteración = 18
# Iteración 19: f_min = [0.223 0.303], Jacobiano =
# [[-0.8  0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.3905 0.0623]
# Energías: inferior = 0.223, superior = 0.303
# v0 = -54.356014999999964, vls = -6.924244999999983, Iteración = 19
# Iteración 20: f_min = [0.209 0.289], Jacobiano =
# [[-0.8  0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.3695 0.0609]
# Energías: inferior = 0.209, superior = 0.289
# v0 = -54.33753999999996, vls = -6.921199999999984, Iteración = 20
# Iteración 21: f_min = [0.196 0.275], Jacobiano =
# [[-0.8  0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.3218 0.0316]
# Energías: inferior = 0.196, superior = 0.275
# v0 = -54.32144999999996, vls = -6.919619999999984, Iteración = 21
# Iteración 22: f_min = [0.184 0.264], Jacobiano =
# [[-0.8  0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.3056 0.032 ]
# Energías: inferior = 0.184, superior = 0.264
# v0 = -54.30616999999996, vls = -6.918019999999982, Iteración = 22
# Iteración 23: f_min = [0.173 0.254], Jacobiano =
# [[-0.8  0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.3162 0.0578]
# Energías: inferior = 0.173, superior = 0.254
# v0 = -54.29035999999996, vls = -6.915129999999982, Iteración = 23
# Iteración 24: f_min = [0.162 0.242], Jacobiano =
# [[-0.8  0.3]
#  [-0.6 -0.5]]
# Gradiente = [0.2748 0.0724]
# Energías: inferior = 0.162, superior = 0.242
# v0 = -54.27661999999996, vls = -6.911509999999981, Iteración = 24
# Iteración 25: f_min = [0.152 0.232], Jacobiano =
# [[-0.7  0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.2688 0.0552]
# Energías: inferior = 0.152, superior = 0.232
# v0 = -54.263179999999956, vls = -6.90874999999998, Iteración = 25
# Iteración 26: f_min = [0.143 0.222], Jacobiano =
# [[-0.8  0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.2698 0.0538]
# Energías: inferior = 0.143, superior = 0.222
# v0 = -54.24968999999995, vls = -6.906059999999979, Iteración = 26
# Iteración 27: f_min = [0.133 0.212], Jacobiano =
# [[-0.7  0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.2415 0.0528]
# Energías: inferior = 0.133, superior = 0.212
# v0 = -54.237614999999956, vls = -6.903419999999979, Iteración = 27
# Iteración 28: f_min = [0.125 0.203], Jacobiano =
# [[-0.8  0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.2421 0.0515]
# Energías: inferior = 0.125, superior = 0.203
# v0 = -54.22550999999996, vls = -6.900844999999979, Iteración = 28
# Iteración 29: f_min = [0.117 0.194], Jacobiano =
# [[-0.8  0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.2294 0.0502]
# Energías: inferior = 0.117, superior = 0.194
# v0 = -54.214039999999954, vls = -6.898334999999978, Iteración = 29
# Iteración 30: f_min = [0.109 0.185], Jacobiano =
# [[-0.8  0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.1982 0.0304]
# Energías: inferior = 0.109, superior = 0.185
# v0 = -54.20412999999996, vls = -6.896814999999979, Iteración = 30
# Iteración 31: f_min = [0.102 0.178], Jacobiano =
# [[-0.8  0.3]
#  [-0.6 -0.5]]
# Gradiente = [0.1884 0.0584]
# Energías: inferior = 0.102, superior = 0.178
# v0 = -54.19470999999996, vls = -6.893894999999978, Iteración = 31
# Iteración 32: f_min = [0.095 0.171], Jacobiano =
# [[-0.7  0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.1862 0.0475]
# Energías: inferior = 0.095, superior = 0.171
# v0 = -54.18539999999996, vls = -6.891519999999978, Iteración = 32
# Iteración 33: f_min = [0.089 0.164], Jacobiano =
# [[-0.8  0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.186  0.0464]
# Energías: inferior = 0.089, superior = 0.164
# v0 = -54.17609999999996, vls = -6.8891999999999785, Iteración = 33
# Iteración 34: f_min = [0.083 0.157], Jacobiano =
# [[-0.8  0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.1763 0.0453]
# Energías: inferior = 0.083, superior = 0.157
# v0 = -54.167284999999964, vls = -6.88693499999998, Iteración = 34
# Iteración 35: f_min = [0.077 0.15 ], Jacobiano =
# [[-0.8  0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.1666 0.0442]
# Energías: inferior = 0.077, superior = 0.15
# v0 = -54.15895499999996, vls = -6.88472499999998, Iteración = 35
# Iteración 36: f_min = [0.071 0.143], Jacobiano =
# [[-0.8  0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.1426 0.0288]
# Energías: inferior = 0.071, superior = 0.143
# v0 = -54.15182499999996, vls = -6.88328499999998, Iteración = 36
# Iteración 37: f_min = [0.066 0.138], Jacobiano =
# [[-0.8  0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.1356 0.0426]
# Energías: inferior = 0.066, superior = 0.138
# v0 = -54.14504499999996, vls = -6.881154999999981, Iteración = 37
# Iteración 38: f_min = [0.062 0.133], Jacobiano =
# [[-0.8  0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.1427 0.0417]
# Energías: inferior = 0.062, superior = 0.133
# v0 = -54.13790999999996, vls = -6.87906999999998, Iteración = 38
# Iteración 39: f_min = [0.057 0.127], Jacobiano =
# [[-0.8  0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.1218 0.028 ]
# Energías: inferior = 0.057, superior = 0.127
# v0 = -54.13181999999996, vls = -6.87766999999998, Iteración = 39
# Iteración 40: f_min = [0.053 0.123], Jacobiano =
# [[-0.8  0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.1285 0.0403]
# Energías: inferior = 0.053, superior = 0.123
# v0 = -54.12539499999996, vls = -6.875654999999979, Iteración = 40
# Iteración 41: f_min = [0.049 0.118], Jacobiano =
# [[-0.8  0.3]
#  [-0.7 -0.5]]
# Gradiente = [0.1218 0.0443]
# Energías: inferior = 0.049, superior = 0.118
# v0 = -54.11930499999996, vls = -6.873439999999979, Iteración = 41
# Iteración 42: f_min = [0.045 0.113], Jacobiano =
# [[-0.8  0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.1151 0.0385]
# Energías: inferior = 0.045, superior = 0.113
# v0 = -54.11354999999996, vls = -6.871514999999979, Iteración = 42
# Iteración 43: f_min = [0.041 0.108], Jacobiano =
# [[-0.8  0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0976 0.0376]
# Energías: inferior = 0.041, superior = 0.108
# v0 = -54.10866999999996, vls = -6.869634999999978, Iteración = 43
# Iteración 44: f_min = [0.038 0.104], Jacobiano =
# [[-0.8  0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0928 0.0368]
# Energías: inferior = 0.038, superior = 0.104
# v0 = -54.10402999999996, vls = -6.867794999999978, Iteración = 44
# Iteración 45: f_min = [0.035 0.1  ], Jacobiano =
# [[-0.8  0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.088 0.026]
# Energías: inferior = 0.035, superior = 0.1
# v0 = -54.09962999999996, vls = -6.866494999999978, Iteración = 45
# Iteración 46: f_min = [0.032 0.097], Jacobiano =
# [[-0.8  0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0935 0.0357]
# Energías: inferior = 0.032, superior = 0.097
# v0 = -54.09495499999996, vls = -6.864709999999978, Iteración = 46
# Iteración 47: f_min = [0.029 0.093], Jacobiano =
# [[-0.8  0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0883 0.0349]
# Energías: inferior = 0.029, superior = 0.093
# v0 = -54.09053999999996, vls = -6.862964999999979, Iteración = 47
# Iteración 48: f_min = [0.026 0.089], Jacobiano =
# [[-0.7  0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0716 0.0252]
# Energías: inferior = 0.026, superior = 0.089
# v0 = -54.08695999999996, vls = -6.861704999999978, Iteración = 48
# Iteración 49: f_min = [0.024 0.086], Jacobiano =
# [[-0.8  0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0708 0.0248]
# Energías: inferior = 0.024, superior = 0.086
# v0 = -54.08341999999996, vls = -6.860464999999978, Iteración = 49
# Iteración 50: f_min = [0.022 0.084], Jacobiano =
# [[-0.8  0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0764 0.0332]
# Energías: inferior = 0.022, superior = 0.084
# v0 = -54.079599999999964, vls = -6.858804999999979, Iteración = 50
# Iteración 51: f_min = [0.019 0.08 ], Jacobiano =
# [[-0.7  0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0613 0.0244]
# Energías: inferior = 0.019, superior = 0.08
# v0 = -54.076534999999964, vls = -6.857584999999979, Iteración = 51
# Iteración 52: f_min = [0.018 0.078], Jacobiano =
# [[-0.8  0.3]
#  [-0.7 -0.5]]
# Gradiente = [0.069  0.0336]
# Energías: inferior = 0.018, superior = 0.078
# v0 = -54.07308499999996, vls = -6.855904999999979, Iteración = 52
# Iteración 53: f_min = [0.016 0.075], Jacobiano =
# [[-0.8  0.3]
#  [-0.7 -0.5]]
# Gradiente = [0.0653 0.0327]
# Energías: inferior = 0.016, superior = 0.075
# v0 = -54.069819999999964, vls = -6.854269999999978, Iteración = 53
# Iteración 54: f_min = [0.014 0.072], Jacobiano =
# [[-0.8  0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0616 0.0304]
# Energías: inferior = 0.014, superior = 0.072
# v0 = -54.06673999999997, vls = -6.852749999999978, Iteración = 54
# Iteración 55: f_min = [0.012 0.069], Jacobiano =
# [[-0.8  0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.051  0.0228]
# Energías: inferior = 0.012, superior = 0.069
# v0 = -54.06418999999997, vls = -6.851609999999979, Iteración = 55
# Iteración 56: f_min = [0.01  0.067], Jacobiano =
# [[-0.7  0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0472 0.0295]
# Energías: inferior = 0.01, superior = 0.067
# v0 = -54.061829999999965, vls = -6.850134999999979, Iteración = 56
# Iteración 57: f_min = [0.009 0.065], Jacobiano =
# [[-0.8  0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0527 0.0289]
# Energías: inferior = 0.009, superior = 0.065
# v0 = -54.05919499999997, vls = -6.848689999999979, Iteración = 57
# Iteración 58: f_min = [0.008 0.062], Jacobiano =
# [[-0.8  0.3]
#  [-0.6 -0.4]]
# Gradiente = [0.0436 0.0224]
# Energías: inferior = 0.008, superior = 0.062
# v0 = -54.057014999999964, vls = -6.847569999999979, Iteración = 58
# Iteración 59: f_min = [0.006 0.061], Jacobiano =
# [[-0.5  0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0457 0.0281]
# Energías: inferior = 0.006, superior = 0.061
# v0 = -54.054729999999964, vls = -6.84616499999998, Iteración = 59
# Iteración 60: f_min = [0.005 0.058], Jacobiano =
# [[-0.2  0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0358 0.0212]
# Energías: inferior = 0.005, superior = 0.058
# v0 = -54.052939999999964, vls = -6.84510499999998, Iteración = 60
# Iteración 61: f_min = [0.004 0.057], Jacobiano =
# [[ 1.77635684e-13  4.00000000e-01]
#  [-7.00000000e-01 -5.00000000e-01]]
# Gradiente = [0.0399 0.0269]
# Energías: inferior = 0.004, superior = 0.057
# v0 = -54.05094499999996, vls = -6.843759999999979, Iteración = 61
# Iteración 62: f_min = [0.003 0.055], Jacobiano =
# [[ 0.2  0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0379 0.0263]
# Energías: inferior = 0.003, superior = 0.055
# v0 = -54.049049999999966, vls = -6.842444999999979, Iteración = 62
# Iteración 63: f_min = [0.002 0.053], Jacobiano =
# [[ 0.4  0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.031  0.0257]
# Energías: inferior = 0.002, superior = 0.053
# v0 = -54.047499999999964, vls = -6.841159999999979, Iteración = 63
# Iteración 64: f_min = [0.001 0.051], Jacobiano =
# [[ 0.5  0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0301 0.02  ]
# Energías: inferior = 0.001, superior = 0.051
# v0 = -54.04599499999996, vls = -6.84015999999998, Iteración = 64
# Iteración 65: f_min = [0.001 0.05 ], Jacobiano =
# [[ 0.6  0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0294 0.0246]
# Energías: inferior = 0.001, superior = 0.05
# v0 = -54.044524999999965, vls = -6.838929999999979, Iteración = 65
# Iteración 66: f_min = [1.77635684e-15 4.90000000e-02], Jacobiano =
# [[ 0.8  0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0343 0.0245]
# Energías: inferior = 0.0, superior = 0.049
# v0 = -54.04280999999997, vls = -6.837704999999979, Iteración = 66
# Iteración 67: f_min = [0.001 0.047], Jacobiano =
# [[ 0.8  0.2]
#  [-0.7 -0.5]]
# Gradiente = [0.0321 0.0233]
# Energías: inferior = 0.001, superior = 0.047
# v0 = -54.04120499999997, vls = -6.836539999999979, Iteración = 67
# Iteración 68: f_min = [0.002 0.045], Jacobiano =
# [[ 7.00000000e-01 -1.77635684e-13]
#  [-6.00000000e-01 -4.00000000e-01]]
# Gradiente = [0.0256 0.018 ]
# Energías: inferior = 0.002, superior = 0.045
# v0 = -54.03992499999997, vls = -6.835639999999979, Iteración = 68
# Iteración 69: f_min = [0.002 0.044], Jacobiano =
# [[ 8.00000000e-01 -1.77635684e-13]
#  [-6.00000000e-01 -5.00000000e-01]]
# Gradiente = [0.0248 0.022 ]
# Energías: inferior = 0.002, superior = 0.044
# v0 = -54.038684999999965, vls = -6.834539999999979, Iteración = 69
# Iteración 70: f_min = [0.003 0.043], Jacobiano =
# [[ 0.8 -0.2]
#  [-0.7 -0.5]]
# Gradiente = [0.0277 0.0221]
# Energías: inferior = 0.003, superior = 0.043
# v0 = -54.037299999999966, vls = -6.833434999999979, Iteración = 70
# Iteración 71: f_min = [0.004 0.041], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0218 0.018 ]
# Energías: inferior = 0.004, superior = 0.041
# v0 = -54.03620999999997, vls = -6.83253499999998, Iteración = 71
# Iteración 72: f_min = [0.004 0.04 ], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0208 0.0176]
# Energías: inferior = 0.004, superior = 0.04
# v0 = -54.035169999999965, vls = -6.831654999999979, Iteración = 72
# Iteración 73: f_min = [0.004 0.039], Jacobiano =
# [[ 0.8 -0.3]
#  [-0.6 -0.5]]
# Gradiente = [0.0202 0.0207]
# Energías: inferior = 0.004, superior = 0.039
# v0 = -54.034159999999964, vls = -6.830619999999979, Iteración = 73
# Iteración 74: f_min = [0.005 0.038], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0188 0.021 ]
# Energías: inferior = 0.005, superior = 0.038
# v0 = -54.033219999999965, vls = -6.829569999999979, Iteración = 74
# Iteración 75: f_min = [0.005 0.037], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0219 0.0205]
# Energías: inferior = 0.005, superior = 0.037
# v0 = -54.032124999999965, vls = -6.828544999999979, Iteración = 75
# Iteración 76: f_min = [0.006 0.036], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.021  0.0204]
# Energías: inferior = 0.006, superior = 0.036
# v0 = -54.031074999999966, vls = -6.827524999999979, Iteración = 76
# Iteración 77: f_min = [0.006 0.035], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0197 0.0199]
# Energías: inferior = 0.006, superior = 0.035
# v0 = -54.030089999999966, vls = -6.82652999999998, Iteración = 77
# Iteración 78: f_min = [0.006 0.033], Jacobiano =
# [[ 0.8 -0.3]
#  [-0.6 -0.4]]
# Gradiente = [0.015 0.015]
# Energías: inferior = 0.006, superior = 0.033
# v0 = -54.02933999999997, vls = -6.8257799999999795, Iteración = 78
# Iteración 79: f_min = [0.007 0.033], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0182 0.0193]
# Energías: inferior = 0.007, superior = 0.033
# v0 = -54.02842999999997, vls = -6.82481499999998, Iteración = 79
# Iteración 80: f_min = [0.007 0.032], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0168 0.0188]
# Energías: inferior = 0.007, superior = 0.032
# v0 = -54.027589999999975, vls = -6.82387499999998, Iteración = 80
# Iteración 81: f_min = [0.007 0.031], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0161 0.0183]
# Energías: inferior = 0.007, superior = 0.031
# v0 = -54.026784999999975, vls = -6.82295999999998, Iteración = 81
# Iteración 82: f_min = [0.008 0.03 ], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0154 0.0182]
# Energías: inferior = 0.008, superior = 0.03
# v0 = -54.02601499999997, vls = -6.8220499999999795, Iteración = 82
# Iteración 83: f_min = [0.008 0.029], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0139 0.0177]
# Energías: inferior = 0.008, superior = 0.029
# v0 = -54.02531999999997, vls = -6.821164999999979, Iteración = 83
# Iteración 84: f_min = [0.008 0.028], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0132 0.0172]
# Energías: inferior = 0.008, superior = 0.028
# v0 = -54.024659999999976, vls = -6.820304999999979, Iteración = 84
# Iteración 85: f_min = [0.008 0.027], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0098 0.0167]
# Energías: inferior = 0.008, superior = 0.027
# v0 = -54.02416999999998, vls = -6.819469999999979, Iteración = 85
# Iteración 86: f_min = [0.008 0.026], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0092 0.0136]
# Energías: inferior = 0.008, superior = 0.026
# v0 = -54.02370999999998, vls = -6.818789999999979, Iteración = 86
# Iteración 87: f_min = [0.008 0.026], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0118 0.0162]
# Energías: inferior = 0.008, superior = 0.026
# v0 = -54.02311999999998, vls = -6.817979999999979, Iteración = 87
# Iteración 88: f_min = [0.009 0.025], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0087 0.0161]
# Energías: inferior = 0.009, superior = 0.025
# v0 = -54.022684999999974, vls = -6.817174999999979, Iteración = 88
# Iteración 89: f_min = [0.009 0.024], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0081 0.0132]
# Energías: inferior = 0.009, superior = 0.024
# v0 = -54.022279999999974, vls = -6.8165149999999795, Iteración = 89
# Iteración 90: f_min = [0.009 0.024], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0105 0.0156]
# Energías: inferior = 0.009, superior = 0.024
# v0 = -54.02175499999997, vls = -6.81573499999998, Iteración = 90
# Iteración 91: f_min = [0.009 0.023], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0075 0.0151]
# Energías: inferior = 0.009, superior = 0.023
# v0 = -54.02137999999997, vls = -6.81497999999998, Iteración = 91
# Iteración 92: f_min = [0.009 0.023], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0098 0.0151]
# Energías: inferior = 0.009, superior = 0.023
# v0 = -54.02088999999997, vls = -6.81422499999998, Iteración = 92
# Iteración 93: f_min = [0.009 0.022], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0082 0.0146]
# Energías: inferior = 0.009, superior = 0.022
# v0 = -54.02047999999997, vls = -6.81349499999998, Iteración = 93
# Iteración 94: f_min = [0.009 0.021], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0054 0.012 ]
# Energías: inferior = 0.009, superior = 0.021
# v0 = -54.02020999999997, vls = -6.812894999999981, Iteración = 94
# Iteración 95: f_min = [0.009 0.021], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0075 0.0141]
# Energías: inferior = 0.009, superior = 0.021
# v0 = -54.01983499999997, vls = -6.812189999999981, Iteración = 95
# Iteración 96: f_min = [0.009 0.02 ], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0048 0.0116]
# Energías: inferior = 0.009, superior = 0.02
# v0 = -54.019594999999974, vls = -6.81160999999998, Iteración = 96
# Iteración 97: f_min = [0.009 0.02 ], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0068 0.0136]
# Energías: inferior = 0.009, superior = 0.02
# v0 = -54.01925499999997, vls = -6.81092999999998, Iteración = 97
# Iteración 98: f_min = [0.009 0.019], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0042 0.0112]
# Energías: inferior = 0.009, superior = 0.019
# v0 = -54.01904499999997, vls = -6.81036999999998, Iteración = 98
# Iteración 99: f_min = [0.009 0.019], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.007  0.0131]
# Energías: inferior = 0.009, superior = 0.019
# v0 = -54.01869499999997, vls = -6.80971499999998, Iteración = 99
# Iteración 100: f_min = [0.009 0.018], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0045 0.0108]
# Energías: inferior = 0.009, superior = 0.018
# v0 = -54.01846999999997, vls = -6.80917499999998, Iteración = 100
# Iteración 101: f_min = [0.009 0.018], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0045 0.0126]
# Energías: inferior = 0.009, superior = 0.018
# v0 = -54.01824499999997, vls = -6.80854499999998, Iteración = 101
# Iteración 102: f_min = [0.009 0.017], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0039 0.0104]
# Energías: inferior = 0.009, superior = 0.017
# v0 = -54.018049999999974, vls = -6.80802499999998, Iteración = 102
# Iteración 103: f_min = [0.009 0.017], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0039 0.0121]
# Energías: inferior = 0.009, superior = 0.017
# v0 = -54.017854999999976, vls = -6.80741999999998, Iteración = 103
# Iteración 104: f_min = [0.008 0.017], Jacobiano =
# [[ 0.8 -0.3]
#  [-0.7 -0.5]]
# Gradiente = [0.0055 0.0109]
# Energías: inferior = 0.008, superior = 0.017
# v0 = -54.017579999999974, vls = -6.80687499999998, Iteración = 104
# Iteración 105: f_min = [0.008 0.016], Jacobiano =
# [[ 0.8 -0.3]
#  [-0.6 -0.4]]
# Gradiente = [0.0032 0.0088]
# Energías: inferior = 0.008, superior = 0.016
# v0 = -54.01741999999997, vls = -6.80643499999998, Iteración = 105
# Iteración 106: f_min = [0.008 0.016], Jacobiano =
# [[ 0.8 -0.3]
#  [-0.6 -0.5]]
# Gradiente = [0.0032 0.0104]
# Energías: inferior = 0.008, superior = 0.016
# v0 = -54.01725999999997, vls = -6.80591499999998, Iteración = 106
# Iteración 107: f_min = [0.008 0.016], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0048 0.0112]
# Energías: inferior = 0.008, superior = 0.016
# v0 = -54.017019999999974, vls = -6.80535499999998, Iteración = 107
# Iteración 108: f_min = [0.008 0.015], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0026 0.0092]
# Energías: inferior = 0.008, superior = 0.015
# v0 = -54.016889999999975, vls = -6.80489499999998, Iteración = 108
# Iteración 109: f_min = [0.008 0.015], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0026 0.0107]
# Energías: inferior = 0.008, superior = 0.015
# v0 = -54.01675999999998, vls = -6.8043599999999795, Iteración = 109
# Iteración 110: f_min = [0.008 0.015], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0041 0.0107]
# Energías: inferior = 0.008, superior = 0.015
# v0 = -54.016554999999975, vls = -6.803824999999979, Iteración = 110
# Iteración 111: f_min = [0.008 0.014], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.002  0.0088]
# Energías: inferior = 0.008, superior = 0.014
# v0 = -54.01645499999997, vls = -6.803384999999979, Iteración = 111
# Iteración 112: f_min = [0.008 0.014], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.002  0.0102]
# Energías: inferior = 0.008, superior = 0.014
# v0 = -54.01635499999997, vls = -6.802874999999979, Iteración = 112
# Iteración 113: f_min = [0.008 0.014], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0034 0.0102]
# Energías: inferior = 0.008, superior = 0.014
# v0 = -54.01618499999997, vls = -6.802364999999979, Iteración = 113
# Iteración 114: f_min = [0.008 0.013], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0014 0.0084]
# Energías: inferior = 0.008, superior = 0.013
# v0 = -54.01611499999997, vls = -6.801944999999979, Iteración = 114
# Iteración 115: f_min = [0.008 0.013], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0022 0.0097]
# Energías: inferior = 0.008, superior = 0.013
# v0 = -54.01600499999997, vls = -6.801459999999978, Iteración = 115
# Iteración 116: f_min = [0.008 0.013], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0035 0.0097]
# Energías: inferior = 0.008, superior = 0.013
# v0 = -54.01582999999997, vls = -6.800974999999978, Iteración = 116
# Iteración 117: f_min = [0.008 0.012], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0016 0.008 ]
# Energías: inferior = 0.008, superior = 0.012
# v0 = -54.015749999999976, vls = -6.800574999999978, Iteración = 117
# Iteración 118: f_min = [0.007 0.012], Jacobiano =
# [[ 0.8 -0.3]
#  [-0.6 -0.4]]
# Gradiente = [0.0016 0.0069]
# Energías: inferior = 0.007, superior = 0.012
# v0 = -54.01566999999998, vls = -6.800229999999978, Iteración = 118
# Iteración 119: f_min = [0.007 0.012], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0016 0.0088]
# Energías: inferior = 0.007, superior = 0.012
# v0 = -54.01558999999998, vls = -6.799789999999978, Iteración = 119
# Iteración 120: f_min = [0.007 0.012], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0028 0.0088]
# Energías: inferior = 0.007, superior = 0.012
# v0 = -54.01544999999998, vls = -6.799349999999977, Iteración = 120
# Iteración 121: f_min = [0.007 0.011], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.001  0.0072]
# Energías: inferior = 0.007, superior = 0.011
# v0 = -54.01539999999998, vls = -6.798989999999978, Iteración = 121
# Iteración 122: f_min = [0.007 0.011], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.001  0.0072]
# Energías: inferior = 0.007, superior = 0.011
# v0 = -54.01534999999998, vls = -6.798629999999978, Iteración = 122
# Iteración 123: f_min = [0.007 0.011], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.001  0.0083]
# Energías: inferior = 0.007, superior = 0.011
# v0 = -54.015299999999975, vls = -6.798214999999978, Iteración = 123
# Iteración 124: f_min = [0.007 0.011], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0021 0.0083]
# Energías: inferior = 0.007, superior = 0.011
# v0 = -54.01519499999998, vls = -6.797799999999977, Iteración = 124
# Iteración 125: f_min = [0.007 0.011], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0021 0.0083]
# Energías: inferior = 0.007, superior = 0.011
# v0 = -54.01508999999998, vls = -6.797384999999977, Iteración = 125
# Iteración 126: f_min = [0.007 0.01 ], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0011 0.0068]
# Energías: inferior = 0.007, superior = 0.01
# v0 = -54.015034999999976, vls = -6.797044999999978, Iteración = 126
# Iteración 127: f_min = [0.007 0.01 ], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0011 0.0078]
# Energías: inferior = 0.007, superior = 0.01
# v0 = -54.01497999999997, vls = -6.796654999999977, Iteración = 127
# Iteración 128: f_min = [0.006 0.01 ], Jacobiano =
# [[ 0.8 -0.3]
#  [-0.7 -0.5]]
# Gradiente = [0.0022 0.0068]
# Energías: inferior = 0.006, superior = 0.01
# v0 = -54.01486999999997, vls = -6.796314999999978, Iteración = 128
# Iteración 129: f_min = [0.006 0.01 ], Jacobiano =
# [[ 0.8 -0.3]
#  [-0.7 -0.5]]
# Gradiente = [0.0022 0.0068]
# Energías: inferior = 0.006, superior = 0.01
# v0 = -54.014759999999974, vls = -6.795974999999978, Iteración = 129
# Iteración 130: f_min = [0.006 0.009], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0006 0.006 ]
# Energías: inferior = 0.006, superior = 0.009
# v0 = -54.01472999999997, vls = -6.795674999999978, Iteración = 130
# Iteración 131: f_min = [0.006 0.009], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0006 0.006 ]
# Energías: inferior = 0.006, superior = 0.009
# v0 = -54.01469999999997, vls = -6.795374999999978, Iteración = 131
# Iteración 132: f_min = [0.006 0.009], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0006 0.0069]
# Energías: inferior = 0.006, superior = 0.009
# v0 = -54.01466999999997, vls = -6.7950299999999775, Iteración = 132
# Iteración 133: f_min = [0.006 0.009], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0015 0.0069]
# Energías: inferior = 0.006, superior = 0.009
# v0 = -54.014594999999964, vls = -6.794684999999977, Iteración = 133
# Iteración 134: f_min = [0.006 0.009], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0015 0.0069]
# Energías: inferior = 0.006, superior = 0.009
# v0 = -54.01451999999996, vls = -6.794339999999977, Iteración = 134
# Iteración 135: f_min = [0.006 0.008], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [-1.0662346e-15  5.6000000e-03]
# Energías: inferior = 0.006, superior = 0.008
# v0 = -54.01451999999996, vls = -6.794059999999977, Iteración = 135
# Iteración 136: f_min = [0.006 0.008], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [-1.0662346e-15  5.6000000e-03]
# Energías: inferior = 0.006, superior = 0.008
# v0 = -54.01451999999996, vls = -6.793779999999977, Iteración = 136
# Iteración 137: f_min = [0.006 0.008], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [-1.0662346e-15  5.6000000e-03]
# Energías: inferior = 0.006, superior = 0.008
# v0 = -54.01451999999996, vls = -6.793499999999977, Iteración = 137
# Iteración 138: f_min = [0.006 0.008], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0006 0.0064]
# Energías: inferior = 0.006, superior = 0.008
# v0 = -54.01448999999996, vls = -6.7931799999999765, Iteración = 138
# Iteración 139: f_min = [0.006 0.008], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0006 0.0064]
# Energías: inferior = 0.006, superior = 0.008
# v0 = -54.01445999999996, vls = -6.792859999999976, Iteración = 139
# Iteración 140: f_min = [0.005 0.008], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0016 0.006 ]
# Energías: inferior = 0.005, superior = 0.008
# v0 = -54.01437999999996, vls = -6.792559999999976, Iteración = 140
# Iteración 141: f_min = [0.005 0.008], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0016 0.006 ]
# Energías: inferior = 0.005, superior = 0.008
# v0 = -54.01429999999996, vls = -6.792259999999976, Iteración = 141
# Iteración 142: f_min = [0.005 0.007], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0002 0.0048]
# Energías: inferior = 0.005, superior = 0.007
# v0 = -54.01428999999996, vls = -6.792019999999976, Iteración = 142
# Iteración 143: f_min = [0.005 0.007], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0002 0.0048]
# Energías: inferior = 0.005, superior = 0.007
# v0 = -54.01427999999996, vls = -6.791779999999976, Iteración = 143
# Iteración 144: f_min = [0.005 0.007], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [0.0002 0.0048]
# Energías: inferior = 0.005, superior = 0.007
# v0 = -54.014269999999954, vls = -6.791539999999976, Iteración = 144
# Iteración 145: f_min = [0.005 0.007], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0002 0.0055]
# Energías: inferior = 0.005, superior = 0.007
# v0 = -54.01425999999995, vls = -6.791264999999976, Iteración = 145
# Iteración 146: f_min = [0.005 0.007], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0009 0.0055]
# Energías: inferior = 0.005, superior = 0.007
# v0 = -54.01421499999995, vls = -6.790989999999976, Iteración = 146
# Iteración 147: f_min = [0.005 0.007], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0009 0.0055]
# Energías: inferior = 0.005, superior = 0.007
# v0 = -54.01416999999995, vls = -6.790714999999976, Iteración = 147
# Iteración 148: f_min = [0.005 0.007], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.7 -0.5]]
# Gradiente = [0.0009 0.0055]
# Energías: inferior = 0.005, superior = 0.007
# v0 = -54.01412499999995, vls = -6.790439999999975, Iteración = 148
# Iteración 149: f_min = [0.005 0.006], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [-0.0004  0.0044]
# Energías: inferior = 0.005, superior = 0.006
# v0 = -54.01414499999995, vls = -6.790219999999976, Iteración = 149
# Iteración 150: f_min = [0.005 0.006], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [1.0e-04 4.4e-03]
# Energías: inferior = 0.005, superior = 0.006
# v0 = -54.01413999999995, vls = -6.789999999999976, Iteración = 150
# Iteración 151: f_min = [0.005 0.006], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.6 -0.4]]
# Gradiente = [1.0e-04 4.4e-03]
# Energías: inferior = 0.005, superior = 0.006
# v0 = -54.014134999999946, vls = -6.789779999999976, Iteración = 151
# Iteración 152: f_min = [0.004 0.006], Jacobiano =
# [[ 0.8 -0.3]
#  [-0.6 -0.5]]
# Gradiente = [0.0004 0.0042]
# Energías: inferior = 0.004, superior = 0.006
# v0 = -54.01411499999995, vls = -6.789569999999976, Iteración = 152
# Iteración 153: f_min = [0.004 0.006], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.6 -0.5]]
# Gradiente = [0.0004 0.0046]
# Energías: inferior = 0.004, superior = 0.006
# v0 = -54.01409499999995, vls = -6.789339999999976, Iteración = 153
# Iteración 154: f_min = [0.004 0.006], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.5 -0.5]]
# Gradiente = [-0.0002  0.0046]
# Energías: inferior = 0.004, superior = 0.006
# v0 = -54.01410499999995, vls = -6.789109999999976, Iteración = 154
# Iteración 155: f_min = [0.004 0.006], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.5 -0.5]]
# Gradiente = [-0.0002  0.0046]
# Energías: inferior = 0.004, superior = 0.006
# v0 = -54.014114999999954, vls = -6.788879999999976, Iteración = 155
# Iteración 156: f_min = [0.004 0.006], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.5 -0.5]]
# Gradiente = [-0.0002  0.0046]
# Energías: inferior = 0.004, superior = 0.006
# v0 = -54.01412499999996, vls = -6.788649999999976, Iteración = 156
# Iteración 157: f_min = [0.004 0.006], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.5 -0.5]]
# Gradiente = [-0.0002  0.0046]
# Energías: inferior = 0.004, superior = 0.006
# v0 = -54.01413499999996, vls = -6.7884199999999755, Iteración = 157
# Iteración 158: f_min = [0.004 0.005], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.4 -0.4]]
# Gradiente = [-0.0012  0.0036]
# Energías: inferior = 0.004, superior = 0.005
# v0 = -54.01419499999996, vls = -6.788239999999975, Iteración = 158
# Iteración 159: f_min = [0.004 0.005], Jacobiano =
# [[ 0.8 -0.4]
#  [-0.4 -0.4]]
# Gradiente = [-0.0012  0.0036]
# Energías: inferior = 0.004, superior = 0.005
# v0 = -54.014254999999956, vls = -6.788059999999975, Iteración = 159
# Iteración 160: f_min = [0.004 0.005], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.4 -0.4]]
# Gradiente = [-0.0008  0.0036]
# Energías: inferior = 0.004, superior = 0.005
# v0 = -54.014294999999954, vls = -6.787879999999975, Iteración = 160
# Iteración 161: f_min = [0.004 0.005], Jacobiano =
# [[ 0.7 -0.4]
#  [-0.4 -0.4]]
# Gradiente = [-0.0008  0.0036]
# Energías: inferior = 0.004, superior = 0.005
# v0 = -54.01433499999995, vls = -6.787699999999974, Iteración = 161
# Iteración 162: f_min = [0.003 0.005], Jacobiano =
# [[ 0.8 -0.3]
#  [-0.4 -0.4]]
# Gradiente = [-0.0004  0.0029]
# Energías: inferior = 0.003, superior = 0.005
# v0 = -54.01435499999995, vls = -6.7875549999999745, Iteración = 162
# Iteración 163: f_min = [0.003 0.005], Jacobiano =
# [[ 0.8 -0.3]
#  [-0.4 -0.4]]
# Gradiente = [-0.0004  0.0029]
# Energías: inferior = 0.003, superior = 0.005
# v0 = -54.01437499999995, vls = -6.787409999999975, Iteración = 163
# Iteración 164: f_min = [0.003 0.005], Jacobiano =
# [[ 0.8 -0.2]
#  [-0.4 -0.4]]
# Gradiente = [-0.0004  0.0026]
# Energías: inferior = 0.003, superior = 0.005
# v0 = -54.01439499999995, vls = -6.787279999999974, Iteración = 164
# Iteración 165: f_min = [0.003 0.005], Jacobiano =
# [[ 0.8 -0.2]
#  [-0.4 -0.5]]
# Gradiente = [-0.0004  0.0031]
# Energías: inferior = 0.003, superior = 0.005
# v0 = -54.01441499999995, vls = -6.787124999999974, Iteración = 165
# Iteración 166: f_min = [0.003 0.005], Jacobiano =
# [[ 0.8 -0.2]
#  [-0.4 -0.5]]
# Gradiente = [-0.0004  0.0031]
# Energías: inferior = 0.003, superior = 0.005
# v0 = -54.01443499999995, vls = -6.7869699999999735, Iteración = 166
# Iteración 167: f_min = [0.003 0.005], Jacobiano =
# [[ 0.8 -0.2]
#  [-0.4 -0.5]]
# Gradiente = [-0.0004  0.0031]
# Energías: inferior = 0.003, superior = 0.005
# v0 = -54.01445499999995, vls = -6.786814999999973, Iteración = 167
# Iteración 168: f_min = [0.003 0.005], Jacobiano =
# [[ 0.8 -0.2]
#  [-0.4 -0.5]]
# Gradiente = [-0.0004  0.0031]
# Energías: inferior = 0.003, superior = 0.005
# v0 = -54.01447499999995, vls = -6.786659999999973, Iteración = 168
# Iteración 169: f_min = [0.003 0.005], Jacobiano =
# [[ 0.8 -0.2]
#  [-0.3 -0.5]]
# Gradiente = [-0.0009  0.0031]
# Energías: inferior = 0.003, superior = 0.005
# v0 = -54.01451999999995, vls = -6.7865049999999725, Iteración = 169
# Iteración 170: f_min = [0.003 0.005], Jacobiano =
# [[ 0.8 -0.2]
#  [-0.3 -0.5]]
# Gradiente = [-0.0009  0.0031]
# Energías: inferior = 0.003, superior = 0.005
# v0 = -54.01456499999995, vls = -6.786349999999972, Iteración = 170
# Iteración 171: f_min = [0.003 0.005], Jacobiano =
# [[ 0.8 -0.2]
#  [-0.3 -0.5]]
# Gradiente = [-0.0009  0.0031]
# Energías: inferior = 0.003, superior = 0.005
# v0 = -54.01460999999995, vls = -6.786194999999972, Iteración = 171
# Iteración 172: f_min = [0.003 0.005], Jacobiano =
# [[ 0.7 -0.2]
#  [-0.3 -0.5]]
# Gradiente = [-0.0006  0.0031]
# Energías: inferior = 0.003, superior = 0.005
# v0 = -54.01463999999995, vls = -6.786039999999971, Iteración = 172
# Iteración 173: f_min = [0.003 0.005], Jacobiano =
# [[ 0.7 -0.2]
#  [-0.3 -0.5]]
# Gradiente = [-0.0006  0.0031]
# Energías: inferior = 0.003, superior = 0.005
# v0 = -54.01466999999995, vls = -6.785884999999971, Iteración = 173
# Iteración 174: f_min = [0.003 0.005], Jacobiano =
# [[ 0.7 -0.2]
#  [-0.3 -0.5]]
# Gradiente = [-0.0006  0.0031]
# Energías: inferior = 0.003, superior = 0.005
# v0 = -54.014699999999955, vls = -6.785729999999971, Iteración = 174
# Iteración 175: f_min = [0.002 0.005], Jacobiano =
# [[ 0.8 -0.1]
#  [-0.3 -0.5]]
# Gradiente = [-0.0001  0.0027]
# Energías: inferior = 0.002, superior = 0.005
# v0 = -54.01470499999996, vls = -6.7855949999999705, Iteración = 175
# Iteración 176: f_min = [0.002 0.005], Jacobiano =
# [[ 8.00000000e-01 -1.77635684e-13]
#  [-3.00000000e-01 -5.00000000e-01]]
# Gradiente = [-0.0001  0.0025]
# Energías: inferior = 0.002, superior = 0.005
# v0 = -54.01470999999996, vls = -6.785469999999971, Iteración = 176
# Iteración 177: f_min = [0.002 0.004], Jacobiano =
# [[ 8.00000000e-01 -1.77635684e-13]
#  [-2.00000000e-01 -4.00000000e-01]]
# Gradiente = [-0.0008  0.0016]
# Energías: inferior = 0.002, superior = 0.004
# v0 = -54.01474999999996, vls = -6.785389999999971, Iteración = 177
# Iteración 178: f_min = [0.002 0.004], Jacobiano =
# [[ 8.00000000e-01 -1.77635684e-13]
#  [-2.00000000e-01 -4.00000000e-01]]
# Gradiente = [-0.0008  0.0016]
# Energías: inferior = 0.002, superior = 0.004
# v0 = -54.014789999999955, vls = -6.7853099999999715, Iteración = 178
# Iteración 179: f_min = [0.002 0.004], Jacobiano =
# [[ 8.00000000e-01 -1.77635684e-13]
#  [-2.00000000e-01 -4.00000000e-01]]
# Gradiente = [-0.0008  0.0016]
# Energías: inferior = 0.002, superior = 0.004
# v0 = -54.014829999999954, vls = -6.785229999999972, Iteración = 179
# Iteración 180: f_min = [0.002 0.004], Jacobiano =
# [[ 8.00000000e-01 -1.77635684e-13]
#  [-2.00000000e-01 -4.00000000e-01]]
# Gradiente = [-0.0008  0.0016]
# Energías: inferior = 0.002, superior = 0.004
# v0 = -54.01486999999995, vls = -6.785149999999972, Iteración = 180
# Iteración 181: f_min = [0.002 0.004], Jacobiano =
# [[ 8.00000000e-01 -1.77635684e-13]
#  [-2.00000000e-01 -4.00000000e-01]]
# Gradiente = [-0.0008  0.0016]
# Energías: inferior = 0.002, superior = 0.004
# v0 = -54.01490999999995, vls = -6.785069999999973, Iteración = 181
# Iteración 182: f_min = [0.002 0.004], Jacobiano =
# [[ 8.00000000e-01 -1.77635684e-13]
#  [-2.00000000e-01 -4.00000000e-01]]
# Gradiente = [-0.0008  0.0016]
# Energías: inferior = 0.002, superior = 0.004
# v0 = -54.01494999999995, vls = -6.784989999999973, Iteración = 182
# Iteración 183: f_min = [0.002 0.004], Jacobiano =
# [[ 8.00000000e-01 -1.77635684e-13]
#  [-2.00000000e-01 -4.00000000e-01]]
# Gradiente = [-0.0008  0.0016]
# Energías: inferior = 0.002, superior = 0.004
# v0 = -54.01498999999995, vls = -6.784909999999973, Iteración = 183
# Iteración 184: f_min = [0.002 0.004], Jacobiano =
# [[ 8.00000000e-01 -1.77635684e-13]
#  [-2.00000000e-01 -4.00000000e-01]]
# Gradiente = [-0.0008  0.0016]
# Energías: inferior = 0.002, superior = 0.004
# v0 = -54.015029999999946, vls = -6.784829999999974, Iteración = 184
# Iteración 185: f_min = [0.002 0.004], Jacobiano =
# [[ 8.00000000e-01 -1.77635684e-13]
#  [-2.00000000e-01 -4.00000000e-01]]
# Gradiente = [-0.0008  0.0016]
# Energías: inferior = 0.002, superior = 0.004
# v0 = -54.015069999999945, vls = -6.784749999999974, Iteración = 185
# Iteración 186: f_min = [0.002 0.004], Jacobiano =
# [[ 8.00000000e-01 -1.77635684e-13]
#  [-2.00000000e-01 -4.00000000e-01]]
# Gradiente = [-0.0008  0.0016]
# Energías: inferior = 0.002, superior = 0.004
# v0 = -54.01510999999994, vls = -6.784669999999974, Iteración = 186
# Iteración 187: f_min = [0.002 0.004], Jacobiano =
# [[ 7.00000000e-01 -1.77635684e-13]
#  [-2.00000000e-01 -4.00000000e-01]]
# Gradiente = [-0.0006  0.0016]
# Energías: inferior = 0.002, superior = 0.004
# v0 = -54.015139999999946, vls = -6.784589999999975, Iteración = 187
# Iteración 188: f_min = [0.002 0.004], Jacobiano =
# [[ 7.00000000e-01 -1.77635684e-13]
#  [-2.00000000e-01 -4.00000000e-01]]
# Gradiente = [-0.0006  0.0016]
# Energías: inferior = 0.002, superior = 0.004
# v0 = -54.01516999999995, vls = -6.784509999999975, Iteración = 188
# Iteración 189: f_min = [0.002 0.004], Jacobiano =
# [[ 7.00000000e-01 -1.77635684e-13]
#  [-2.00000000e-01 -4.00000000e-01]]
# Gradiente = [-0.0006  0.0016]
# Energías: inferior = 0.002, superior = 0.004
# v0 = -54.01519999999995, vls = -6.7844299999999755, Iteración = 189
# Iteración 190: f_min = [0.002 0.004], Jacobiano =
# [[ 7.00000000e-01 -1.77635684e-13]
#  [-2.00000000e-01 -4.00000000e-01]]
# Gradiente = [-0.0006  0.0016]
# Energías: inferior = 0.002, superior = 0.004
# v0 = -54.01522999999995, vls = -6.784349999999976, Iteración = 190
# Iteración 191: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.1]
#  [-0.2 -0.4]]
# Gradiente = [-1.42111219e-15  1.50000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.01522999999995, vls = -6.784274999999976, Iteración = 191
# Iteración 192: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.1]
#  [-0.2 -0.4]]
# Gradiente = [-1.42111219e-15  1.50000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.01522999999995, vls = -6.784199999999976, Iteración = 192
# Iteración 193: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.1]
#  [-0.2 -0.4]]
# Gradiente = [-1.42111219e-15  1.50000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.01522999999995, vls = -6.784124999999976, Iteración = 193
# Iteración 194: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.4]]
# Gradiente = [-1.42111219e-15  1.40000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.01522999999995, vls = -6.784054999999976, Iteración = 194
# Iteración 195: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.4]]
# Gradiente = [-1.42111219e-15  1.40000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.01522999999995, vls = -6.783984999999976, Iteración = 195
# Iteración 196: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.3]]
# Gradiente = [-1.42111219e-15  1.00000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.01522999999995, vls = -6.7839349999999765, Iteración = 196
# Iteración 197: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.3]]
# Gradiente = [-1.42111219e-15  1.00000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.01522999999995, vls = -6.783884999999977, Iteración = 197
# Iteración 198: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.3]]
# Gradiente = [-1.42111219e-15  1.00000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.01522999999995, vls = -6.783834999999977, Iteración = 198
# Iteración 199: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.3]]
# Gradiente = [-1.42111219e-15  1.00000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.01522999999995, vls = -6.783784999999977, Iteración = 199
# Iteración 200: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.3]]
# Gradiente = [-1.42111219e-15  1.00000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.01522999999995, vls = -6.783734999999977, Iteración = 200
# Iteración 201: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.3]]
# Gradiente = [-1.42111219e-15  1.00000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.01522999999995, vls = -6.783684999999977, Iteración = 201
# Iteración 202: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.3]]
# Gradiente = [-1.42111219e-15  1.00000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.01522999999995, vls = -6.783634999999977, Iteración = 202
# Iteración 203: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.3]]
# Gradiente = [-1.42111219e-15  1.00000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.01522999999995, vls = -6.783584999999977, Iteración = 203
# Iteración 204: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.3]]
# Gradiente = [-1.42111219e-15  1.00000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.01522999999995, vls = -6.783534999999977, Iteración = 204
# Iteración 205: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.2 -0.3]]
# Gradiente = [-1.42111219e-15  1.00000000e-03]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.01522999999995, vls = -6.783484999999978, Iteración = 205
# Iteración 206: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.1 -0.3]]
# Gradiente = [-0.0004  0.001 ]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.01524999999995, vls = -6.783434999999978, Iteración = 206
# Iteración 207: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.1 -0.3]]
# Gradiente = [-0.0004  0.001 ]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.01526999999995, vls = -6.783384999999978, Iteración = 207
# Iteración 208: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.1 -0.3]]
# Gradiente = [-0.0004  0.001 ]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.01528999999995, vls = -6.783334999999978, Iteración = 208
# Iteración 209: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.1 -0.3]]
# Gradiente = [-0.0004  0.001 ]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.01530999999995, vls = -6.783284999999978, Iteración = 209
# Iteración 210: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.1 -0.3]]
# Gradiente = [-0.0004  0.001 ]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.01532999999995, vls = -6.783234999999978, Iteración = 210
# Iteración 211: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.1 -0.3]]
# Gradiente = [-0.0004  0.001 ]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.01534999999995, vls = -6.783184999999978, Iteración = 211
# Iteración 212: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.1 -0.3]]
# Gradiente = [-0.0004  0.001 ]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.01536999999995, vls = -6.783134999999978, Iteración = 212
# Iteración 213: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.1 -0.3]]
# Gradiente = [-0.0004  0.001 ]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.01538999999995, vls = -6.7830849999999785, Iteración = 213
# Iteración 214: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.1 -0.3]]
# Gradiente = [-0.0004  0.001 ]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.015409999999946, vls = -6.783034999999979, Iteración = 214
# Iteración 215: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.1 -0.3]]
# Gradiente = [-0.0004  0.001 ]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.015429999999945, vls = -6.782984999999979, Iteración = 215
# Iteración 216: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.1 -0.3]]
# Gradiente = [-0.0004  0.001 ]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.015449999999944, vls = -6.782934999999979, Iteración = 216
# Iteración 217: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.1 -0.3]]
# Gradiente = [-0.0004  0.001 ]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.015469999999944, vls = -6.782884999999979, Iteración = 217
# Iteración 218: f_min = [0.001 0.004], Jacobiano =
# [[ 0.8  0.2]
#  [-0.1 -0.3]]
# Gradiente = [-0.0004  0.001 ]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.01548999999994, vls = -6.782834999999979, Iteración = 218
# Iteración 219: f_min = [0.001 0.004], Jacobiano =
# [[ 0.7  0.2]
#  [-0.1 -0.3]]
# Gradiente = [-0.0003  0.001 ]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.01550499999994, vls = -6.782784999999979, Iteración = 219
# Iteración 220: f_min = [0.001 0.004], Jacobiano =
# [[ 0.7  0.2]
#  [-0.1 -0.3]]
# Gradiente = [-0.0003  0.001 ]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.01551999999994, vls = -6.782734999999979, Iteración = 220
# Iteración 221: f_min = [0.001 0.004], Jacobiano =
# [[ 0.7  0.2]
#  [-0.1 -0.3]]
# Gradiente = [-0.0003  0.001 ]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.015534999999936, vls = -6.782684999999979, Iteración = 221
# Iteración 222: f_min = [0.001 0.004], Jacobiano =
# [[ 0.7  0.2]
#  [-0.1 -0.3]]
# Gradiente = [-0.0003  0.001 ]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.015549999999934, vls = -6.7826349999999795, Iteración = 222
# Iteración 223: f_min = [0.001 0.004], Jacobiano =
# [[ 0.7  0.2]
#  [-0.1 -0.3]]
# Gradiente = [-0.0003  0.001 ]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.01556499999993, vls = -6.78258499999998, Iteración = 223
# Iteración 224: f_min = [0.001 0.004], Jacobiano =
# [[ 0.7  0.2]
#  [-0.1 -0.3]]
# Gradiente = [-0.0003  0.001 ]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.01557999999993, vls = -6.78253499999998, Iteración = 224
# Iteración 225: f_min = [0.001 0.004], Jacobiano =
# [[ 0.7  0.2]
#  [-0.1 -0.3]]
# Gradiente = [-0.0003  0.001 ]
# Energías: inferior = 0.001, superior = 0.004
# v0 = -54.01559499999993, vls = -6.78248499999998, Iteración = 225
# Iteración 226: f_min = [1.77635684e-15 4.00000000e-03], Jacobiano =
# [[ 0.8  0.3]
#  [-0.1 -0.3]]
# Gradiente = [0.0004 0.0012]
# Energías: inferior = 0.0, superior = 0.004
# v0 = -54.01557499999993, vls = -6.78242499999998, Iteración = 226
# Iteración 227: f_min = [1.77635684e-15 4.00000000e-03], Jacobiano =
# [[ 0.8  0.3]
#  [-0.1 -0.3]]
# Gradiente = [0.0004 0.0012]
# Energías: inferior = 0.0, superior = 0.004
# v0 = -54.01555499999993, vls = -6.782364999999981, Iteración = 227
# Iteración 228: f_min = [1.77635684e-15 4.00000000e-03], Jacobiano =
# [[ 0.8  0.3]
#  [-0.1 -0.3]]
# Gradiente = [0.0004 0.0012]
# Energías: inferior = 0.0, superior = 0.004
# v0 = -54.01553499999993, vls = -6.782304999999981, Iteración = 228
# Iteración 229: f_min = [1.77635684e-15 4.00000000e-03], Jacobiano =
# [[ 0.8  0.3]
#  [-0.1 -0.3]]
# Gradiente = [0.0004 0.0012]
# Energías: inferior = 0.0, superior = 0.004
# v0 = -54.01551499999993, vls = -6.782244999999982, Iteración = 229
# Iteración 230: f_min = [1.77635684e-15 4.00000000e-03], Jacobiano =
# [[ 0.8  0.3]
#  [-0.1 -0.3]]
# Gradiente = [0.0004 0.0012]
# Energías: inferior = 0.0, superior = 0.004
# Converged after 230 iterations.
# Minimum found at:
#  V_0 = -54.01549499999993, V_LS = -6.782184999999982
